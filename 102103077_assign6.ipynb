# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus_interview.pkl')
data
# Out:
#                                                 transcript          full_name
# BERGMAN  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMOVIES \n\n\n\n\...       SCOTT PELLEY
# CARLSON  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOLITICS \n\n\n\...          JOHN GRAY
# DENNETT  \n\n\n\n\n\n\n\n\n\n\nDan Dennett: Interview w...     TUCKER CARLSON
# FALLACI  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHISTORY \n\n\n\n...        JON STEWART
# GRAY     \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBOOKS \n\n\n\n\n...     ORIANA FALLACI
# Goodman  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMOVIES \n\n\n\n\...       Oliver Stone
# HARARI   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCULTURE \n\n\n\n...     INGMAR BERGMAN
# PELLEY   \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMOVIES \n\n\n\n\...      Susan Goodman
# STEWART  \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCOMEDY \n\n\n\n\...  YUVAL NOAH HARARI
# Stone    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCOMEDY \n\n\n\n\...              ELLEN

# %%
# Extract only Carlson's text
letter_text = data.transcript.loc['CARLSON']
letter_text[:200]
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOLITICS \n\n\n\n\n\n\n\nTucker Carlson Interviews Vladimir Putin | Transcript \n\n\n\n\n\n\n\nFebruary 10, 2024 \n\n\n\n\n\n\n\n\t\t\tPutin's interview with Tucker Carlson: Discusses Russia-Ukraine history, crit"

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Carlson's routine, take a look at it
letter_dict = markov_chain(letter_text)
letter_dict
# Out:
# {'\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOLITICS': ['\n\n\n\n\n\n\n\nTucker'],
#  '\n\n\n\n\n\n\n\nTucker': ['Carlson'],
#  'Carlson': ['Interviews', '[Introducing'],
#  'Interviews': ['Vladimir'],
#  'Vladimir': ['Putin', 'Putin', 'Putin,', 'Putin', 'himself', 'in', 'Putin'],
#  'Putin': ['|',
#   'provided',
#   'expressed',
#   'addressed',
#   'hinted',
#   'portrayed',
#   'went',
#   'believes',
#   'provided',
#   '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSHARE'],
#  '|': ['Transcript'],
#  'Transcript': ['\n\n\n\n\n\n\n\nFebruary'],
#  '\n\n\n\n\n\n\n\nFebruary': ['10,'],
#  '10,': ['2024'],
#  '2024': ["\n\n\n\n\n\n\n\n\t\t\tPutin's"],
#  "\n\n\n\n\n\n\n\n\t\t\tPutin's": ['interview'],
#  'interview': ['with', 'with'],
#  'with': ['Tucker',
#   'Tucker',
#   'Orthodox',
#   'what',
#   'the',
#   'it',
#   'that,',
#   'Ukraine',
#   'two',
#   'its',
#   'Poland.',
#   'Poland',
#   'Poland',
#   'Russia.',
#   'Poland.',
#   'Poland',
#   'Hitler\xa0—',
#   'Hitler,',
#   'East',
#   'Hitler',
#   'Hitler',
#   'Hitler.',
#   'Poland.5\nBy\xa0the\xa0way,',
#   'people',
#   'Ukraine',
#   'no',
#   'you,',
#   'me',
#   'the\xa0Soviet',
#   'the\xa0Soviet',
#   'praise,',
#   'Orthodox',
#   'the\xa0outgoing',
#   'its',
#   'Ukraine',
#   'the\xa0United',
#   'my\xa0colleague,',
#   'the\xa0President?“',
#   'the\xa0opposition',
#   'us',
#   'President',
#   'some',
#   'intercontinental',
#   'whom?',
#   'Russia.',
#   'Russia.',
#   'a\xa0good',
#   'him',
#   'visits,',
#   'the\xa0EU',
#   'Ukraine',
#   'Ukraine',
#   'Russia',
#   'the\xa0EU?',
#   'the\xa0use',
#   'the\xa0fact',
#   'us.',
#   'NATO',
#   'a\xa0gun',
#   'the\xa0help',
#   'nothing',
#   'Hitler.\nI\xa0have',
#   'Russia.',
#   'Hitler,',
#   'torches,',
#   'the\xa0territory',
#   'the\xa0entire',
#   'Russia.',
#   'Russia.',
#   'an\xa0imaginary',
#   'us',
#   'Russia',
#   'mercenaries',
#   'migration,',
#   'the\xa0national',
#   'Russia?',
#   'cheap',
#   'third',
#   'your',
#   'China.',
#   'them.',
#   'China',
#   'Europe',
#   'China.\nIt',
#   'China,',
#   'the\xa0dollar.\nSo,',
#   'the\xa0US',
#   'my\xa0colleague',
#   'China',
#   'China',
#   'the\xa0events',
#   'regard',
#   'regard',
#   'him.',
#   'Trump',
#   'Russia',
#   'the\xa0Soviet',
#   'China.',
#   'the\xa0Soviet',
#   'the\xa0economy',
#   'the\xa0Minsk',
#   'neo-Nazis',
#   'Russia\xa0–',
#   'you',
#   'Ukraine',
#   'Russia.',
#   'this',
#   'us.',
#   'each',
#   'me,',
#   'that,',
#   'the\xa0inherent',
#   'Genghis',
#   'the\xa0Roman',
#   'what',
#   'him,',
#   'him',
#   'one',
#   'one',
#   'respect,',
#   'special',
#   'success.',
#   'success',
#   'the\xa0war',
#   'the\xa0Biden',
#   'a\xa0way',
#   'dignity.',
#   'traditional',
#   'expanding',
#   'Poland',
#   'historical',
#   'Russia',
#   'Hitler',
#   'Hitler',
#   'Nazi',
#   'Czechoslovakia,',
#   'Germany.\nDanzig',
#   'specific',
#   'no',
#   'neighboring'],
#  'Tucker': ['Carlson:', 'Carlson,', 'Carlson,'],
#  'Carlson:': ['Discusses',
#   'That',
#   'May',
#   'It’s',
#   'Right.\nVladimir',
#   'In\xa01654?\nVladimir',
#   'You',
#   'Do',
#   'Have',
#   'Do',
#   'What',
#   'Would',
#   'Really,',
#   'Of\xa0course!\nVladimir',
#   'Right.',
#   'Well,',
#   'You',
#   'But',
#   'What',
#   'I\xa0just',
#   'Do',
#   'But',
#   'So',
#   'So',
#   'What',
#   'I\xa0appreciate',
#   'So,',
#   'But',
#   'Evan',
#   'He',
#   'I\xa0hope',
#   'I\xa0wonder',
#   'Well,',
#   'So,',
#   'Do',
#   'Would',
#   'Thank'],
#  'Discusses': ['Russia-Ukraine'],
#  'Russia-Ukraine': ['history,'],
#  'history,': ['criticizes'],
#  'criticizes': ['NATO,'],
#  'NATO,': ['sanctions', 'do', 'the\xa0US,', 'you'],
#  'sanctions': ['impact,',
#   'imposed',
#   'against',
#   'against',
#   'in\xa0everything,'],
#  'impact,': ['and'],
#  'and': ['advocates',
#   'enduring',
#   'Ukraine,',
#   'its',
#   'a',
#   'diversifying',
#   'a',
#   'genetic',
#   'traditional',
#   'materialistic',
#   'could',
#   'reluctance',
#   'cultural',
#   'most',
#   'that’s',
#   'found',
#   'interrupted',
#   'he',
#   'you',
#   'actually',
#   'that',
#   'then',
#   'west.',
#   'started',
#   'the',
#   'secure',
#   'the',
#   'under',
#   'although',
#   'went',
#   'Hitler',
#   'yet',
#   'which',
#   'Romania',
#   'Hungary',
#   'given',
#   'they',
#   'the',
#   'consolidating',
#   'the',
#   'Mongol',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'its',
#   'Poland',
#   'the',
#   'expansion',
#   'the',
#   'independence',
#   'their',
#   'correction',
#   'partitioning',
#   'the',
#   'the',
#   'Germany.',
#   'the',
#   'Danzig',
#   'the',
#   'misleading.',
#   'the',
#   'Soviet',
#   'the',
#   'the',
#   'forced',
#   'the',
#   'territorial',
#   'the',
#   'misrepresents',
#   'motivations.',
#   'the',
#   'political',
#   'policies',
#   'the',
#   'cannot',
#   'the',
#   'the',
#   'the',
#   'Romania,',
#   'reflects',
#   'states',
#   'political',
#   'politically',
#   'condenses',
#   'Russia’s',
#   'relationships',
#   'the',
#   'influence',
#   'contested',
#   'other',
#   'critical',
#   'the',
#   'Criminals\t\t\t\n\n\nThat'],
#  'advocates': ['for'],
#  'for': ['dialogue',
#   'global',
#   'a',
#   'what',
#   'their',
#   'Ukrainian',
#   'some',
#   'sure.',
#   'the',
#   'Ukrainian',
#   'historical',
#   'example,',
#   'the',
#   'logic'],
#  'dialogue': ['&', 'with', 'between'],
#  '&': ['peace\t\t\n\n\n\n'],
#  'peace\t\t\n\n\n\n': ['\n\n\n\nIn'],
#  '\n\n\n\nIn': ['an'],
#  'an': ['extensive',
#   'interview',
#   'imminent',
#   'hour,',
#   'artificial',
#   'opportunistic',
#   '“artificial'],
#  'extensive': ['dialogue'],
#  'Carlson,': ['Vladimir', 'we', 'Vladimir'],
#  'provided': ['a',
#   'for\xa0in\xa0the\xa0Constitution',
#   'by\xa0law.',
#   'contains',
#   'account,',
#   'is'],
#  'a': ['detailed',
#   'critique',
#   'contravention',
#   'direct',
#   'readiness',
#   'perceived',
#   'contrast',
#   'diplomatic',
#   'threat,',
#   'very',
#   'filibustering',
#   'filibustering',
#   'historic',
#   'sincere',
#   'quote,',
#   'surprise',
#   'talk',
#   'good',
#   'truce',
#   'peace',
#   'special',
#   'very',
#   'breakdown',
#   'federation',
#   'political',
#   'significant',
#   'distinct',
#   'national',
#   'Ukrainian',
#   'complex',
#   'small',
#   'matter',
#   'collaboration',
#   'cooperative',
#   'sovereign',
#   'trigger',
#   'two-front',
#   'Soviet',
#   'perspective',
#   'subject',
#   'highly',
#   'perspective',
#   'continuous',
#   'specific',
#   'Comment',
#   'deep'],
#  'detailed': ['exposition'],
#  'exposition': ['on'],
#  'on': ['the',
#   'the',
#   'the',
#   'the',
#   'February',
#   'for',
#   'the',
#   'our',
#   'Russia,',
#   'the',
#   'that.',
#   '1',
#   'established',
#   'historical',
#   'the',
#   'the',
#   'Putin’s'],
#  'the': ['historical',
#   'strategic',
#   'counterproductive',
#   'West,',
#   'US',
#   'ongoing',
#   'lack',
#   'West’s',
#   'burgeoning',
#   'imperative',
#   'essence',
#   'pragmatic',
#   'detention',
#   'possibility',
#   'West.',
#   'interview,',
#   'West’s',
#   'video]:',
#   'President',
#   'building',
#   'Kremlin.',
#   'war',
#   'war',
#   'beginning',
#   'interview,',
#   'most',
#   'history',
#   '8th',
#   'interruption.',
#   'end,',
#   'interview;',
#   'conflict',
#   'conclusion',
#   'United',
#   'United',
#   'blue.',
#   'United',
#   'Poles',
#   'Russian',
#   'fact',
#   'Russian',
#   'war',
#   'whole',
#   'Dnieper,',
#   'entire',
#   'Dnieper',
#   'rule',
#   'Great,',
#   'south',
#   'Revolution.3',
#   'ideas',
#   'ideas',
#   'Ukrainianization.',
#   'potential',
#   'border',
#   'idea',
#   'Austrian',
#   '19th',
#   '1917',
#   'Bolsheviks',
#   'statehood,',
#   'Civil',
#   'hostilities',
#   'right',
#   'Dnieper',
#   'partitioning',
#   'Poles',
#   'Danzig',
#   'war',
#   'USSR',
#   'founder',
#   'Soviet',
#   'USSR.',
#   'lands',
#   'Black',
#   'Great',
#   'lands',
#   'war,',
#   'lands',
#   'Ukraine',
#   'historical',
#   'Russian',
#   'Varangian',
#   'beginning',
#   'Kievan',
#   'establishment',
#   'state',
#   'groundwork',
#   'growth',
#   'beginning',
#   'Christianization',
#   'Rus’',
#   'establishment',
#   'state',
#   'subsequent',
#   '13th',
#   'payment',
#   'surviving',
#   'Grand',
#   'southward',
#   'emerging',
#   'Grand',
#   'Lithuanian',
#   'union',
#   'religious',
#   'Orthodox',
#   'Pope’s',
#   'emergence',
#   'gradual',
#   'Polish-Lithuanian',
#   'borderlands',
#   'development',
#   '1654',
#   'protection',
#   'Tsardom',
#   'eventual',
#   'Great',
#   'Russian',
#   'Great’s',
#   '19th',
#   '19th',
#   'portrayal',
#   'same',
#   'aftermath',
#   'Munich',
#   'outbreak',
#   'Danzig',
#   'city',
#   'narrative',
#   'Danzig',
#   'destruction',
#   'subjugation',
#   'Danzig',
#   'invasion,',
#   'cause',
#   'Molotov-Ribbentrop',
#   'USSR’s',
#   'context',
#   'Soviet',
#   'start',
#   'pact,',
#   'Soviet',
#   'two',
#   'post-war',
#   'borders',
#   'westward',
#   'expulsion',
#   'Baltic',
#   'city',
#   'victorious',
#   'USSR,',
#   'United',
#   'United',
#   'provided',
#   'subsequent',
#   'result',
#   'Soviet',
#   'actions',
#   'role',
#   'Bolsheviks,',
#   'creation',
#   'Soviet',
#   'policies',
#   'nuances',
#   'creation',
#   'USSR’s',
#   'categorization',
#   'core',
#   'interpretation',
#   'framing',
#   'source.',
#   'centuries-long',
#   'role',
#   'West',
#   'war,',
#   'ring',
#   'sheer',
#   'statement',
#   'guiding',
#   'dumbest',
#   'maddest.\n\n\n\n\n\n\n\n\n\n\n\t\t\t\tThe',
#   'Frontlines:',
#   'frontlines.\n\n\n\n\n\n\n\n\n\n\n\n\n\n'],
#  'historical': ['genesis',
#   'background.\nTucker',
#   'lands,',
#   'lands.\nAfter',
#   'connection',
#   'land.\nMoreover,',
#   'homeland.',
#   'accuracy',
#   'knowledge:\nFoundation',
#   'event,',
#   'facts.\nPolonization',
#   'processes.',
#   'records.',
#   'narratives.\n5.\xa0The',
#   'accuracy.',
#   'events',
#   'dynamics.',
#   'connection',
#   'records,',
#   'narratives,',
#   'context'],
#  'genesis': ['and'],
#  'enduring': ['ties'],
#  'ties': ['between', 'with', 'which', 'between'],
#  'between': ['Russia',
#   'Russia',
#   'Russia',
#   'us.',
#   'the\xa0enterprises',
#   'the\xa0Government',
#   'the\xa0opposition',
#   'Russia',
#   'the\xa0special',
#   'the\xa0two',
#   'Russia',
#   'Poland',
#   'Nazi',
#   'the'],
#  'Russia': ['and',
#   'towards',
#   'as',
#   'has',
#   'out',
#   'celebrated',
#   'began',
#   'and\xa0adopted',
#   'reclaimed',
#   'for\xa0hundreds',
#   'received',
#   'had',
#   'and\xa0Ukraine',
#   'even',
#   'was',
#   'and\xa0United',
#   'because',
#   'has',
#   'expected',
#   'could',
#   'protested',
#   'had',
#   'asked',
#   'and\xa0Europe',
#   'than',
#   'itself.',
#   'to\xa0the\xa0bitter',
#   'away.“',
#   'will',
#   'will',
#   'in\xa0the\xa0Ukrainian',
#   'as\xa0much',
#   'will',
#   'pass',
#   'took',
#   'in\xa0the\xa0fifth',
#   'was',
#   'ready?',
#   'could',
#   'and\xa0Ukraine;',
#   'itself,',
#   'expanded',
#   'has',
#   'basically',
#   'their',
#   'to\xa0do',
#   'and',
#   'varies',
#   '(USSR)'],
#  'Ukraine,': ['articulating',
#   'attributing',
#   'certain',
#   'in\xa0fact,',
#   'was',
#   'which',
#   'with',
#   'which',
#   'to\xa0which',
#   'having',
#   'which',
#   'reflects',
#   'and'],
#  'articulating': ['a'],
#  'critique': ['against'],
#  'against': ['the',
#   'whom',
#   'Czechoslovakia,',
#   'missile',
#   'you,',
#   'us,',
#   'the\xa0United',
#   'it',
#   'civilians.',
#   'the\xa0background',
#   'them.',
#   'the\xa0Russians',
#   'the\xa0Russians',
#   'common',
#   'you.',
#   'our',
#   'airplanes,',
#   'Russia.',
#   'Russia?',
#   'the\xa0fascists,',
#   'fascism?',
#   'it.\nIt',
#   'Russia.'],
#  'strategic': ['postures', 'security', 'mistakes'],
#  'postures': ['of'],
#  'of': ['NATO',
#   'earlier',
#   'economic',
#   'progress',
#   'Ukraine',
#   'artificial',
#   'Russian',
#   'Western',
#   'journalist',
#   'a',
#   'Russia,',
#   'course,',
#   'the',
#   'Russia,',
#   'Western',
#   'what',
#   'the',
#   'the',
#   'the',
#   '1654,',
#   'the',
#   'the',
#   'Poland.2\nUnder',
#   'Catherine',
#   'its',
#   'Ukrainianization',
#   'Ukraine',
#   'the',
#   'Czechoslovakia',
#   'the',
#   'Ukraine',
#   'the',
#   'that',
#   'Ukraine.',
#   'the',
#   'their',
#   'Ukraine.',
#   'Putin’s',
#   'the',
#   'the',
#   'what',
#   'Slavic',
#   'it',
#   'Kievan',
#   'Rus’',
#   'Rus’',
#   'the',
#   'the',
#   'Eastern',
#   'Rus’',
#   'tribute',
#   'Lithuania:',
#   'parts',
#   'Rus’',
#   'the',
#   'Lithuania.',
#   'these',
#   'Ukrainian',
#   'Polonization',
#   'a',
#   'the',
#   'a',
#   'the',
#   'Muscovy',
#   'territories',
#   'Catherine',
#   'the',
#   'modern-day',
#   'a',
#   'these',
#   'Czechoslovakia:',
#   'the',
#   'Czechoslovakia',
#   'seizing',
#   'Zaolzie',
#   'World',
#   'the',
#   'Danzig',
#   'contention',
#   'Poland',
#   'Eastern',
#   'his',
#   'a',
#   'World',
#   'the',
#   'its',
#   'influence.',
#   'World',
#   'Poland',
#   'eastern',
#   'Poland’s',
#   'millions',
#   'people.',
#   'Danzig',
#   'broader,',
#   'truth',
#   'World',
#   'actions',
#   'Poland',
#   '20th-century',
#   'Austria-Hungary,',
#   'the',
#   'Soviet',
#   '“Ukrainianization”',
#   'these',
#   'the',
#   'establishing',
#   'Ukraine',
#   '“artificiality”',
#   'debate',
#   'negotiation,',
#   'any',
#   'Rus’,',
#   'these',
#   'historical',
#   'our'],
#  'NATO': ['and',
#   'might',
#   'needs',
#   'expands,',
#   'would',
#   'members',
#   'to\xa0the\xa0East,',
#   'were',
#   'forces,',
#   'was',
#   'or\xa0CIA',
#   'partner',
#   'expansion,',
#   'is',
#   'expansion',
#   'would',
#   'and\xa0US',
#   'would'],
#  'its': ['eastward',
#   'economic',
#   'international',
#   'centre',
#   'historical',
#   'troops',
#   'historical',
#   'Polish',
#   'land',
#   'voice',
#   'resentment,',
#   'own',
#   'independence',
#   'borders',
#   'job',
#   'identity.',
#   'national',
#   'power',
#   'idea',
#   'own',
#   'borders',
#   'consequences:',
#   'proposed',
#   'partition',
#   '“historical',
#   'hat'],
#  'eastward': ['expansion,', 'is'],
#  'expansion,': ['which', 'support'],
#  'which': ['he',
#   'is,',
#   'is,',
#   'was',
#   'had',
#   'connected',
#   'was',
#   'had',
#   'was',
#   'had',
#   'was',
#   'had',
#   'is',
#   'as\xa0many',
#   'I\xa0read',
#   'gained',
#   'had',
#   'is',
#   'the\xa0US',
#   'could',
#   'were',
#   'the\xa0entire',
#   'we',
#   'he',
#   'had',
#   'ended',
#   'was',
#   'also',
#   'brings',
#   'has,',
#   'is,',
#   'are',
#   'would',
#   'is',
#   'is,',
#   'is',
#   'is'],
#  'he': ['views',
#   'perceives',
#   'sees',
#   'responded;',
#   'was',
#   'thinks.',
#   'passed',
#   'began',
#   'transferred',
#   'can',
#   'said:',
#   'got',
#   'said,',
#   'spoke',
#   'said',
#   'raised',
#   'said:',
#   'said,',
#   'will',
#   'would',
#   'had',
#   'said?',
#   'won',
#   'is',
#   'wasn’t',
#   'said',
#   'did',
#   'was',
#   'had',
#   'would',
#   'forbade',
#   'is',
#   'is',
#   'funds,',
#   'say?\nVladimir',
#   'invaded',
#   'has',
#   'was',
#   'made',
#   'understood',
#   'was',
#   'has,',
#   'used',
#   'answered,',
#   'would',
#   'won',
#   'came',
#   'realized',
#   'took',
#   'has',
#   'do',
#   'won',
#   'considers',
#   'was',
#   'still',
#   'publicly',
#   'do',
#   'baptized',
#   'baptized',
#   'will',
#   'is.',
#   'is',
#   'is',
#   'was',
#   'is',
#   'is',
#   'was',
#   'had',
#   'did',
#   'was',
#   'was',
#   'was',
#   'was',
#   'wasn’t',
#   'was',
#   'was',
#   '[bandit]',
#   'drove',
#   'be',
#   'did',
#   'is',
#   'himself'],
#  'views': ['as'],
#  'as': ['a',
#   'the',
#   'amenable',
#   'the',
#   'you',
#   'a',
#   'it',
#   'the',
#   'autonomous',
#   'Western',
#   'a',
#   'the',
#   '“collaborating”',
#   'a',
#   'part',
#   '“very',
#   'a',
#   'an',
#   '“artificial”',
#   'the'],
#  'contravention': ['of'],
#  'earlier': ['assurances', 'by\xa0Genghis'],
#  'assurances': ['and'],
#  'direct': ['threat'],
#  'threat': ['to', 'from', 'mongering.\nTucker', 'coming'],
#  'to': ['Russian',
#   'engage',
#   'resolve',
#   'the',
#   'mitigate',
#   'constructive',
#   'acknowledge',
#   'the',
#   'see',
#   'us',
#   'parts',
#   'view',
#   'the',
#   'American',
#   'launch',
#   'polonize',
#   'say',
#   'the',
#   'struggle',
#   'Warsaw',
#   'Kiev…',
#   'Russia,',
#   'weaken',
#   'a',
#   'restore',
#   'Poland.\nIn\xa01939,',
#   'Hitler’s',
#   'Germany,',
#   'start',
#   'be',
#   'do',
#   'withdraw',
#   'that',
#   'the',
#   'Poland',
#   'Hungary',
#   'the',
#   'affirm',
#   'rule',
#   'Kiev',
#   'Kiev',
#   'residents',
#   'the',
#   'escape',
#   'describe',
#   'start',
#   'cede',
#   'cede',
#   'Czechoslovakia',
#   'its',
#   'the',
#   'the',
#   'Poland',
#   'the',
#   'scholarly',
#   'Ukraine’s',
#   'Ukraine,',
#   'power',
#   'Global',
#   'throw',
#   'ponder',
#   'Fight\t\t\t\n\n\n',
#   'fight,',
#   'avoid',
#   'the'],
#  'Russian': ['security.',
#   'national',
#   'state',
#   'state',
#   'state',
#   'state',
#   'language',
#   'lands',
#   'lands',
#   'state,',
#   'lands',
#   'leadership',
#   'leadership',
#   'people.',
#   'threat.',
#   'invasion',
#   'troops',
#   'authorities',
#   'literature,',
#   'people',
#   'control',
#   'State',
#   'history',
#   'Empire:',
#   'statehood'],
#  'security.': ['He'],
#  'He': ['elaborated',
#   'expounded',
#   'ousted',
#   'wrote',
#   'was',
#   'was',
#   'was',
#   'understood',
#   'says,',
#   'looked',
#   'says,',
#   'wrote',
#   'says,',
#   'came',
#   'personally',
#   'signed',
#   'actually',
#   'was',
#   'was',
#   'came',
#   'talked',
#   'deceived',
#   'considers',
#   'can.\nWe',
#   'still',
#   'even',
#   'said',
#   'was',
#   'was',
#   'committed',
#   'is',
#   'is',
#   'affixed',
#   'put',
#   'is'],
#  'elaborated': ['on'],
#  'counterproductive': ['nature'],
#  'nature': ['of'],
#  'economic': ['sanctions', 'dependency', 'ties,', 'and\xa0even', 'problems.'],
#  'imposed': ['by', 'by\xa0the\xa0Romans.'],
#  'by': ['the',
#   'what',
#   'the',
#   'the',
#   'attacking',
#   'Prince',
#   'Batu',
#   'the',
#   'the',
#   'various',
#   'Polish',
#   'annexing',
#   'Poland’s',
#   'a',
#   'refusing',
#   'assuring',
#   'the',
#   'multiple',
#   'Nazi',
#   'Russians,'],
#  'West,': ['positing'],
#  'positing': ['that'],
#  'that': ['these',
#   'discussions',
#   'it',
#   'Russia',
#   'light:',
#   'you',
#   'the',
#   'sounds',
#   'the',
#   'was',
#   'this',
#   'because',
#   'a\xa0person',
#   'led',
#   'this',
#   'their',
#   'people',
#   'there',
#   'part',
#   'they',
#   'Moscow',
#   'you',
#   'I\xa0am',
#   'is',
#   'their',
#   'act',
#   'people',
#   'territory',
#   'Ukraine',
#   'treaty,',
#   'Poland',
#   'Ukraine,',
#   'you',
#   'if',
#   'doesn’t',
#   'the\xa0war',
#   'those',
#   'they',
#   'newly',
#   'Soviet',
#   'territory',
#   'Ukraine',
#   'had',
#   'does',
#   'Lenin,',
#   'way.',
#   'had',
#   'had',
#   'Ukraine',
#   'was',
#   'they',
#   'he',
#   'Hungarians',
#   'you',
#   'you',
#   'you',
#   'you',
#   'a\xa0fair',
#   'my\xa0long',
#   'Russia',
#   'the\xa0then',
#   'the\xa0fundamentals',
#   'the\xa0Soviet',
#   'this',
#   'a\xa0new',
#   'relations',
#   'happened,',
#   'the\xa0West',
#   'the\xa0West',
#   'after',
#   'it',
#   'NATO',
#   'Yeltsin',
#   'there',
#   'has',
#   'Yeltsin',
#   'let',
#   'everything',
#   'Russia',
#   'if',
#   'is?',
#   'the\xa0United',
#   'proof.',
#   'this',
#   'it',
#   'the\xa0United',
#   'the\xa0United',
#   'it',
#   'is',
#   'will',
#   'it',
#   'the\xa0doors',
#   'Ukraine',
#   'have',
#   'victory,',
#   'treaty',
#   'is.',
#   'supposed',
#   'I\xa0served',
#   'the\xa0US',
#   'was',
#   'provoked',
#   'they',
#   'they',
#   'agreement',
#   'it',
#   'after',
#   'Ukraine',
#   'it',
#   'they',
#   'they',
#   'if',
#   'happen.',
#   'we',
#   '”it',
#   'mean?\nVladimir',
#   'in\xa0the\xa0early',
#   'an\xa0independent',
#   'he',
#   'is',
#   'nationalism',
#   'walk',
#   'Ukrainians',
#   'you',
#   'this',
#   'we',
#   'is',
#   'culture,',
#   'you',
#   'it',
#   'he',
#   'right?\nTucker',
#   'you',
#   'would',
#   'you',
#   'is',
#   'would',
#   'brings',
#   'this',
#   'we',
#   'would',
#   'is',
#   'Russia',
#   'this',
#   'day.',
#   'NATO',
#   'NATO,',
#   'their',
#   'they',
#   'the\xa0world',
#   'the\xa0world',
#   'going',
#   'the\xa0United',
#   'is',
#   'is',
#   'of\xa0the\xa0growth',
#   'they',
#   'they',
#   'you',
#   'the\xa0world',
#   'is',
#   'you',
#   'of\xa0the\xa0G7.',
#   'I\xa0mentioned',
#   'the\xa0world',
#   'in\xa0the\xa0United',
#   'is',
#   'the\xa0world',
#   'the\xa0U.S.',
#   'the\xa0US',
#   'the\xa0leader',
#   'these',
#   'are',
#   'make',
#   'prepare',
#   'Indonesia',
#   'in\xa0the\xa0United',
#   'the\xa0United',
#   'NATO',
#   'was',
#   'arose',
#   'they',
#   'territory',
#   'the\xa0Russians',
#   'limit',
#   'the\xa0Russians',
#   'neo-Nazis',
#   'he',
#   'he',
#   'the\xa0coup',
#   'happened',
#   'decree',
#   'they',
#   'Russia',
#   'is',
#   'mean',
#   'have',
#   'the\xa0main',
#   'the\xa0Motherland',
#   'Christianity',
#   'to\xa0yourself?\nVladimir',
#   'we',
#   'are',
#   'the\xa0development',
#   'there',
#   'all',
#   'Elon',
#   'negligent',
#   'the\xa0threat',
#   'I\xa0think',
#   'we',
#   'we',
#   'if',
#   'this',
#   'and\xa0he',
#   'in\xa0a\xa0conspiratorial',
#   'out',
#   'getting',
#   'he',
#   'information.',
#   'of\xa0his',
#   'is',
#   'the\xa0person',
#   'what’s',
#   'we',
#   'Ukraine',
#   'they',
#   'no',
#   'I\xa0am\xa0—',
#   'was',
#   'chance.”',
#   'is',
#   'started',
#   'NATO',
#   'NATO',
#   'it',
#   'now',
#   'the\xa0Russian',
#   'partly',
#   'require',
#   'Poland',
#   'Poland',
#   'Germany',
#   'Poland',
#   'is',
#   'emphasizes'],
#  'these': ['measures',
#   'technologies',
#   'lands',
#   'documents…\n\n\n\nTucker',
#   'are',
#   'lands',
#   'elements',
#   'countries',
#   'developments',
#   'territories',
#   'people',
#   'agreements',
#   'decisions',
#   'American',
#   'are',
#   'southeastern',
#   'hostilities,',
#   'are',
#   'things.\nTucker',
#   'decisions,',
#   'lands',
#   'movements',
#   'points',
#   'changes',
#   'processes',
#   'events,'],
#  'measures': ['have', 'to\xa0certain'],
#  'have': ['inadvertently',
#   'a',
#   'all',
#   'nuclear',
#   'every',
#   'a\xa0right',
#   'a\xa0part',
#   'not',
#   'a\xa0record',
#   'never',
#   'a\xa0strong',
#   'become',
#   'said',
#   'joined',
#   'joined',
#   'commenced,',
#   'happened',
#   'proof?“',
#   'the\xa0answer',
#   'been',
#   'disputes,',
#   'thought',
#   'come',
#   'come',
#   'built',
#   'always',
#   'led',
#   'always',
#   'seen',
#   'been',
#   'been.',
#   'ruined',
#   'to\xa0do',
#   'been',
#   'never',
#   'stopped',
#   'you',
#   'very',
#   'been',
#   'been',
#   'the\xa0right',
#   'now?\nVladimir',
#   'completely',
#   'to\xa0get',
#   'it',
#   'been.',
#   'domestic',
#   'contacts',
#   'no',
#   'any',
#   'to\xa0be',
#   'been',
#   'to\xa0continue',
#   'anything',
#   'issues',
#   'nothing',
#   'an\xa0alibi,',
#   'evidence',
#   'a\xa0decent',
#   'said',
#   'sanctions,',
#   'here?',
#   'heard',
#   'a\xa0centuries-long',
#   'small',
#   'that',
#   'exceeded',
#   'to\xa0adapt',
#   'to\xa0make',
#   'become',
#   'run',
#   'known',
#   'to\xa0assume',
#   'to\xa0ask.',
#   'said',
#   'repeatedly,',
#   'never',
#   'not',
#   'never',
#   'stopped',
#   'described',
#   'described',
#   'on\xa0you?\nVladimir',
#   'come',
#   'no',
#   'done',
#   'run',
#   'never',
#   'dragged',
#   'been',
#   'been',
#   'to\xa0come',
#   'already',
#   'already',
#   'to\xa0look',
#   'been',
#   'to\xa0bother',
#   'come',
#   'to\xa0think',
#   'driven',
#   'done',
#   'done',
#   'been'],
#  'inadvertently': ['spurred'],
#  'spurred': ['Russia'],
#  'towards': ['reducing', 'diplomatic', 'another', 'Russia.\nViktor', 'the'],
#  'reducing': ['its'],
#  'dependency': ['on'],
#  'US': ['dollar',
#   'presidents',
#   'leadership.\nTucker',
#   'taxpayers',
#   'dollars',
#   'control,'],
#  'dollar': ['and', 'as\xa0a\xa0tool', 'reserves.'],
#  'diversifying': ['its'],
#  'international': ['trade', 'law,'],
#  'trade': ['relations.', 'with', 'transactions', 'one', 'with', 'with', 'is'],
#  'relations.': ['Putin', 'Let’s'],
#  'expressed': ['a', 'his'],
#  'readiness': ['to'],
#  'engage': ['in'],
#  'in': ['negotiations',
#   'Ukraine,',
#   'Gershkovich’s',
#   'the',
#   'progress,',
#   'Ukraine:',
#   'the',
#   'that',
#   'your',
#   'Ukraine',
#   'every',
#   'possession',
#   'the',
#   'the',
#   'Poland',
#   'that',
#   'the',
#   'the',
#   'addition',
#   'this',
#   'Novgorod',
#   '988',
#   'the',
#   'significant',
#   'the',
#   'different',
#   'the',
#   'the',
#   'October',
#   'the',
#   'August',
#   'September',
#   'the',
#   'the',
#   'Eastern',
#   'Eastern',
#   'state',
#   'Putin’s',
#   'this',
#   'the',
#   'the',
#   'Europe'],
#  'negotiations': ['to', 'with', 'indeed.'],
#  'resolve': ['the'],
#  'ongoing': ['conflict', 'and'],
#  'conflict': ['in', 'in', 'started.'],
#  'attributing': ['the'],
#  'lack': ['of'],
#  'progress': ['to'],
#  'West’s': ['continued', 'adversarial'],
#  'continued': ['military', 'to\xa0do'],
#  'military': ['backing',
#   'support',
#   'operation,',
#   'action,',
#   'action?\nVladimir',
#   'activity',
#   'structures',
#   'man.\nThere',
#   'bases'],
#  'backing': ['of'],
#  'Ukraine': ['and',
#   'started',
#   'started',
#   'come',
#   'and',
#   'should',
#   'some',
#   'whatsoever.\nEven',
#   'wasn’t',
#   'was',
#   'that',
#   'was',
#   'received,',
#   'and',
#   'is',
#   'was',
#   'in\xa02008,',
#   'is',
#   'itself.',
#   'which,',
#   'then”.',
#   'was',
#   'did…\nVladimir',
#   'would',
#   'with',
#   'began',
#   'should',
#   'is',
#   'applauds',
#   'into',
#   'the\xa0Vice-President',
#   'to\xa0peace.',
#   'in\xa0Istanbul,',
#   'was',
#   'a\xa0neutral',
#   'and',
#   'as',
#   'as',
#   'Stance\t\t\t\n\n\nThe'],
#  'perceived': ['reluctance', 'territorial'],
#  'reluctance': ['towards', 'to'],
#  'diplomatic': ['engagement.\nFurthermore,', 'resolution,'],
#  'engagement.\nFurthermore,': ['Putin'],
#  'addressed': ['the', 'your', 'Warsaw,', 'the\xa0United'],
#  'burgeoning': ['domains'],
#  'domains': ['of'],
#  'artificial': ['intelligence', 'state'],
#  'intelligence': ['and', 'service.'],
#  'genetic': ['research,'],
#  'research,': ['underscoring'],
#  'underscoring': ['the'],
#  'imperative': ['for'],
#  'global': ['regulatory', 'conflict.', 'development'],
#  'regulatory': ['frameworks'],
#  'frameworks': ['to'],
#  'mitigate': ['potential'],
#  'potential': ['existential',
#   'enemy',
#   'is',
#   'for\xa0the\xa0future',
#   'of\xa0those'],
#  'existential': ['threats'],
#  'threats': ['these', 'from', 'for\xa0us.'],
#  'technologies': ['may'],
#  'may': ['pose.',
#   'say',
#   'seem',
#   'have',
#   'be',
#   'be',
#   'never',
#   'change.\nLook,',
#   'return',
#   'go'],
#  'pose.': ['He'],
#  'expounded': ['on'],
#  'essence': ['of'],
#  'national': ['identity,',
#   'languages',
#   'costumes.',
#   'heroes\xa0–',
#   'heroes',
#   'territory!',
#   'interests,',
#   'identity',
#   'identity',
#   'identity'],
#  'identity,': ['deeply'],
#  'deeply': ['intertwined', 'rooted'],
#  'intertwined': ['with'],
#  'Orthodox': ['Christianity', 'culture', 'Church?', 'population'],
#  'Christianity': ['and', 'is'],
#  'traditional': ['values,', 'values', 'Russian'],
#  'values,': ['drawing'],
#  'drawing': ['a'],
#  'contrast': ['with'],
#  'what': ['he',
#   'he',
#   'it’s',
#   'you’re',
#   'he',
#   'period…',
#   'happened',
#   'got',
#   'the\xa0Russian',
#   'Russia',
#   'he',
#   'do',
#   'is',
#   'was',
#   'the\xa0leadership’s',
#   'happened',
#   'he',
#   'happened,',
#   'year',
#   'you',
#   'kind',
#   'kind',
#   'it',
#   'was',
#   'it',
#   'the\xa0miscalculation',
#   'I\xa0want',
#   'you',
#   'I\xa0think?',
#   'we',
#   'denazification',
#   'denazification',
#   'we',
#   'I\xa0told',
#   'we',
#   'they’re',
#   'happened,',
#   'it',
#   'is',
#   'the\xa0dollar',
#   'comes',
#   'he',
#   'to\xa0do.',
#   'is',
#   'are',
#   'he',
#   'was',
#   'effect',
#   'they',
#   'is',
#   'is',
#   'makes',
#   'makes',
#   'he',
#   'he',
#   'is',
#   'you',
#   'to\xa0do',
#   'would'],
#  'perceives': ['as'],
#  'pragmatic': ['and', 'after'],
#  'materialistic': ['underpinnings'],
#  'underpinnings': ['of'],
#  'Western': ['societies.\nRegarding',
#   'Ukraine.',
#   'Ukraine).',
#   'analysts',
#   'society',
#   'culture'],
#  'societies.\nRegarding': ['the'],
#  'detention': ['of'],
#  'journalist': ['Evan'],
#  'Evan': ['Gershkovich,', 'Gershkovich', 'Gershkovich,'],
#  'Gershkovich,': ['Putin', 'that’s', 'may'],
#  'hinted': ['at'],
#  'at': ['the', 'about', 'the', 'Stalin’s'],
#  'possibility': ['of'],
#  'resolution,': ['suggesting'],
#  'suggesting': ['that', 'he'],
#  'discussions': ['around'],
#  'around': ['such', '862'],
#  'such': ['issues',
#   'a\xa0negative',
#   'a\xa0global,',
#   'strike',
#   'a\xa0tough',
#   'and\xa0such',
#   'alibi.\nTucker',
#   'as\xa0placing',
#   'intention.',
#   'that',
#   'personal',
#   'an\xa0erroneous,'],
#  'issues': ['are', 'are', 'on\xa0the\xa0border,', 'with', 'with'],
#  'are': ['ongoing',
#   'inventing',
#   'documents',
#   'letters',
#   'copies',
#   'making',
#   'now',
#   'they',
#   'Hungarians',
#   'Transylvanians',
#   'coming',
#   'most',
#   'as\xa0bourgeois',
#   'a\xa0market',
#   'also',
#   'being',
#   'elected,',
#   'not',
#   'now',
#   'improving',
#   'made',
#   'the\xa0guarantees?',
#   'these,',
#   'they?',
#   'the\xa0guarantees?',
#   'going',
#   'well',
#   'constantly',
#   'seedlings,',
#   'displayed',
#   'shouted',
#   'part',
#   'a\xa0separate',
#   'saying,',
#   'alive.',
#   'we',
#   'fighting,',
#   'making',
#   'a\xa0citizen',
#   'been',
#   'safe',
#   'interested',
#   'saying',
#   'conveying',
#   'trying',
#   'engaged',
#   'trying',
#   'saying',
#   'just',
#   'mercenaries',
#   'capable',
#   'American',
#   'they',
#   'ready,',
#   'two',
#   'buying',
#   'highly',
#   'now',
#   'printed,',
#   'quickly',
#   'now',
#   'made',
#   'thinking',
#   'you',
#   'cutting',
#   'killing',
#   'neighbours',
#   'used',
#   'always',
#   'still',
#   'facing',
#   'also',
#   'such',
#   'trying',
#   'limiting',
#   'hurting',
#   'no',
#   'counterproductive.',
#   'applied\xa0–',
#   'applied',
#   'describing',
#   'not',
#   'made',
#   'those',
#   'two',
#   'dominant,',
#   'all',
#   'nonetheless',
#   'not',
#   'you',
#   'you',
#   'aggressive',
#   'a\xa0Cristian',
#   'very',
#   'the\xa0traditional',
#   'together,',
#   'very',
#   'specifically',
#   'different',
#   'protecting',
#   'built',
#   'forces',
#   'not',
#   'what',
#   'happening',
#   'asking',
#   'reports',
#   'in\xa0contact',
#   'talking',
#   'willing',
#   'certain',
#   'certain',
#   'you',
#   'people',
#   'not',
#   'essentially',
#   'serving',
#   'keeping',
#   'pursuing.',
#   'ready',
#   'underway,',
#   'you',
#   'you',
#   'willing',
#   'go',
#   'saying\xa0—',
#   'saying',
#   'ready.',
#   'options',
#   'apparently',
#   'in\xa0power',
#   'ready',
#   'willing',
#   'struggling',
#   'at.',
#   'not',
#   'the\xa0Ukranian',
#   'well-documented',
#   'historical',
#   'complex',
#   'accurately',
#   'elements',
#   'broadly',
#   'subject',
#   'accurately',
#   'based',
#   'marked',
#   'demoralized,'],
#  'could': ['potentially',
#   'claim',
#   'not',
#   'tackle',
#   'drastically',
#   'have',
#   'we',
#   'not',
#   'have',
#   'not',
#   'have',
#   'not',
#   'devolve,',
#   'wind',
#   'be',
#   'somehow',
#   'not',
#   'have',
#   'be',
#   'start',
#   'drive',
#   'have',
#   'lead'],
#  'potentially': ['culminate', 'a\xa0nuclear'],
#  'culminate': ['in'],
#  'Gershkovich’s': ['release,'],
#  'release,': ['contingent'],
#  'contingent': ['upon'],
#  'upon': ['reciprocal', 'some', 'invading'],
#  'reciprocal': ['actions', 'steps.\nWhen'],
#  'actions': ['from', 'before', 'and', 'of'],
#  'from': ['the',
#   'Scandinavia,',
#   'father',
#   'the\xa0prince',
#   'the\xa0archives,',
#   'Bogdan',
#   'the',
#   'Ukraine.',
#   'Ukraine?',
#   'then-Leningrad',
#   'the\xa0West',
#   'the\xa0United',
#   'your',
#   'the\xa0United',
#   'Iran.',
#   'someone,',
#   'political',
#   'above.',
#   'Kiev.',
#   'Kiev.\nAs\xa0soon',
#   'Kiev,',
#   'Kiev,',
#   'the\xa0other',
#   'US',
#   'the\xa0State',
#   'the\xa0United',
#   'Poland,',
#   'the\xa0United',
#   'Georgia',
#   'your',
#   'the\xa0German',
#   'pan-European',
#   'Russia.',
#   'Russia',
#   'the\xa0point',
#   'rising,',
#   'your',
#   'SWIFT',
#   'this',
#   'the\xa0elections',
#   'that?',
#   'the\xa0Russian',
#   'them,',
#   'doing',
#   'pagans',
#   'Latin',
#   'their',
#   'nuclear',
#   'unbridled',
#   'negotiating',
#   'Washington.',
#   'real',
#   'there',
#   'Germany,',
#   'Poland,',
#   'a',
#   'the'],
#  'West.': ['Throughout'],
#  'Throughout': ['the'],
#  'interview,': ['Putin', 'as', 'we', 'he’ll'],
#  'portrayed': ['Russia', 'as\xa0some'],
#  'amenable': ['to'],
#  'constructive': ['dialogue,'],
#  'dialogue,': ['yet'],
#  'yet': ['beleaguered', 'they', 'the\xa0armed', 'they'],
#  'beleaguered': ['by'],
#  'sees': ['as', 'fit.'],
#  'adversarial': ['policies'],
#  'policies': ['and', 'by', 'of'],
#  'acknowledge': ['Russia’s'],
#  'Russia’s': ['security', 'development'],
#  'security': ['concerns',
#   'system',
#   'challenge',
#   'services,',
#   'should',
#   'and\xa0stability'],
#  'concerns': ['and'],
#  'cultural': ['ethos.\n\n*'],
#  'ethos.\n\n*': ['*'],
#  '*': ['*\nTucker', '*\nNOTES\n1.'],
#  '*\nTucker': ['Carlson'],
#  '[Introducing': ['the'],
#  'video]:': ['The'],
#  'The': ['following',
#   'interview,',
#   'answer',
#   'account',
#   'baptism',
#   'fragmentation',
#   'Mongol',
#   'narrative',
#   'incorporation',
#   'process',
#   'term',
#   'reference',
#   'subsequent',
#   'emergence',
#   'annexation',
#   'issue',
#   'refusal',
#   'description',
#   'Molotov-Ribbentrop',
#   'statement',
#   'USSR',
#   'onset',
#   'creation',
#   'adjustments',
#   'Soviet',
#   'concept',
#   'historical',
#   'Dangerous'],
#  'following': ['is', 'the\xa0example'],
#  'is': ['an',
#   'primarily',
#   'considered',
#   'a\xa0memorial',
#   'no',
#   'now',
#   'a\xa0translation',
#   'coming',
#   'that',
#   'that',
#   'not',
#   'how',
#   'an',
#   'at\xa0least',
#   'their',
#   'an\xa0infringement….\nTucker',
#   'that',
#   'why',
#   'a\xa0very',
#   'what',
#   'afraid',
#   'growing',
#   'enormous\xa0—',
#   'the\xa0biggest',
#   'growing',
#   'afraid',
#   'no',
#   'important',
#   'that',
#   'over,',
#   'the\xa0result',
#   'the\xa0right',
#   'trying',
#   'the\xa0second',
#   'the\xa0moment',
#   'easy',
#   'even',
#   'not',
#   'incorrect,',
#   'not',
#   'such',
#   'this,',
#   'there,',
#   'a\xa0neutral',
#   'not',
#   'the\xa0south-east',
#   'a\xa0large',
#   'not',
#   'a\xa0coup',
#   'this?',
#   'a\xa0coup.',
#   'pro-Western,',
#   'not',
#   'the\xa0matter',
#   'that',
#   'a\xa0serious',
#   'a\xa0job.\nTechnically',
#   'when',
#   'a\xa0video',
#   'exactly',
#   'to\xa0stop',
#   'an\xa0attempt',
#   'denazification.',
#   'one',
#   'how',
#   'how',
#   'denazification?',
#   'what',
#   'a\xa0very',
#   'the\xa0problem.',
#   'not',
#   'necessary',
#   'well',
#   'silenced',
#   'a\xa0Jew',
#   'very',
#   'quite',
#   'happening',
#   'what',
#   'in\xa0our',
#   'what',
#   'what',
#   'almost',
#   'nothing',
#   'not,',
#   'it?',
#   'it.\nTucker',
#   'putting',
#   'funding',
#   'happening',
#   'easier',
#   'not',
#   'safe',
#   'there',
#   'an\xa0obvious',
#   'a\xa0fake.',
#   'that,',
#   'absolutely',
#   'to\xa0weaken',
#   'a\xa0provocation,',
#   'obvious.\nDo',
#   'developing',
#   'much',
#   'interested“.',
#   'interested,',
#   'interested',
#   'capable',
#   'very',
#   'possible',
#   'cost',
#   'clear',
#   'a\xa0question',
#   'very',
#   'guided',
#   'difficult',
#   'not',
#   'safe',
#   'another',
#   'the\xa0main',
#   'the\xa0second',
#   'where',
#   'what',
#   'like',
#   'breaking',
#   'in\xa0each',
#   'breaking',
#   'divided',
#   'responsible',
#   'more',
#   'still',
#   'the\xa0only',
#   'split',
#   'an\xa0illness,',
#   'a\xa0period',
#   'now',
#   'akin',
#   'one',
#   'the\xa0cornerstone',
#   'minimal.',
#   'about',
#   'about',
#   'the\xa0main',
#   'a\xa0stupid',
#   'going',
#   'down',
#   'a\xa0complete',
#   'self-conceit.',
#   'going',
#   'a\xa0fair',
#   'what',
#   'not',
#   'a\xa0boogeyman',
#   'number',
#   'not',
#   'to\xa0always',
#   'as\xa0follows.',
#   'still',
#   'growing',
#   'higher',
#   'to\xa0your',
#   'a\xa0delicate',
#   'with',
#   'because',
#   'dead',
#   '240',
#   'well-balanced,',
#   'very',
#   'greater',
#   'due',
#   'inevitable.',
#   'like',
#   'about',
#   'changing',
#   'an\xa0obvious',
#   'not',
#   'not',
#   'not',
#   'not',
#   'about',
#   'a\xa0complex',
#   'it',
#   'a\xa0two-stage',
#   'very',
#   'a\xa0policy',
#   'all',
#   'necessary',
#   'a\xa0mistake,',
#   'necessary',
#   'happening',
#   'developing?',
#   'already',
#   'still',
#   'growing',
#   'changing.',
#   'changing.',
#   'your',
#   'how',
#   'written',
#   'a\xa0violation',
#   'a\xa0threat',
#   'a\xa0separate',
#   'better',
#   'beneficial',
#   'the\xa0primary',
#   'flawed.',
#   'recognized',
#   'his',
#   'Russia',
#   'Mr.',
#   'a\xa0good',
#   'central',
#   'her',
#   'absolutely',
#   'that',
#   'one',
#   'the\xa0basis',
#   'indeed',
#   'impossible',
#   'why',
#   'so',
#   'that',
#   'specifically',
#   'very',
#   'in\xa0the\xa0heart.',
#   'so',
#   'very',
#   'more',
#   'more',
#   'bad,',
#   'that',
#   'in\xa0accordance',
#   'probably',
#   'happening',
#   'that',
#   'currently',
#   'now',
#   'going',
#   'impossible',
#   'very',
#   'the\xa0Wall',
#   '32',
#   'a\xa0huge',
#   'no',
#   'that',
#   'obviously',
#   'a\xa0kid',
#   'not',
#   'true,',
#   'in\xa0a\xa0different',
#   'qualified',
#   'exactly',
#   'qualified',
#   'it,',
#   'called',
#   'hardly',
#   'up',
#   'that?',
#   'a\xa0different',
#   'a\xa0thirty-two',
#   'just',
#   'not',
#   'a\xa0journalist',
#   'different,',
#   'an\xa0ongoing',
#   'going',
#   'the\xa0Western',
#   'obviously',
#   'evident.',
#   'happening.\nThe\xa0financial',
#   'a\xa0huge',
#   'why',
#   'making',
#   'insulted,',
#   'it.\nHowever,',
#   'all.',
#   'our',
#   'pointless',
#   'needed?\nTucker',
#   'too',
#   'a\xa0will.\nUp',
#   'difficult',
#   'impossible',
#   'never',
#   'now?\nVladimir',
#   'a\xa0subject',
#   'willing',
#   'not',
#   'not',
#   'our',
#   'a\xa0combat',
#   'a\xa0specific',
#   'an\xa0example',
#   'no',
#   'happening',
#   'still',
#   'anything',
#   'consistent',
#   'historically',
#   'credited',
#   'a',
#   'correctly',
#   'a',
#   'not',
#   'misleading.',
#   'highly',
#   'partially',
#   'controversial',
#   'not',
#   'a',
#   'broadly'],
#  'President': ['of',
#   '24',
#   'in\xa02000.',
#   'Bill',
#   'Bush',
#   'Bush,',
#   'Kuchma\xa0–',
#   'Kuchma,',
#   'and\xa0politician.',
#   'Yanukovich',
#   'himself',
#   'Biden',
#   'Xi',
#   'of\xa0Ukraine'],
#  'Russia,': ['Vladimir',
#   'going',
#   'I',
#   'while',
#   'which',
#   'and\xa0other',
#   'what',
#   'the\xa0United',
#   'to\xa0try'],
#  'Putin,': ['shot'],
#  'shot': ['on'],
#  'February': ['6,', '24,', 'of\xa02022?\nVladimir'],
#  '6,': ['2024,'],
#  '2024,': ['at'],
#  'about': ['7:00',
#   'the',
#   'the',
#   'to',
#   'it,',
#   'this',
#   'Russia,',
#   'who',
#   'the\xa0United',
#   'it.',
#   'the\xa0answer.',
#   'those',
#   'it,“',
#   'it,',
#   'NATO’s',
#   'how',
#   'that',
#   'the\xa0Minsk',
#   'this',
#   'right',
#   'neo-Nazism',
#   'it?',
#   'that?\nVladimir',
#   'resolving',
#   'this',
#   'my\xa0proposal',
#   'it.\nTucker',
#   'this',
#   'it',
#   'it?',
#   'it?\nVladimir',
#   'Nord',
#   'creativity',
#   '3',
#   'the\xa0emission.\nNevertheless,',
#   '80\xa0per',
#   'that?\nVladimir',
#   'self-conceit.',
#   'the\xa0leader,',
#   'the\xa0personality',
#   '2008',
#   'the\xa0personality',
#   'the\xa0elites’',
#   'what',
#   'pressure,',
#   'this.',
#   'this,',
#   'the\xa0culture',
#   'external',
#   'going',
#   'this,',
#   'the\xa0Russian',
#   'the\xa0eternal,',
#   'moral',
#   'someone',
#   'the\xa0“partners”,',
#   'the\xa0matter',
#   'a\xa0person',
#   'other',
#   'how',
#   'dealing',
#   'inflicting',
#   'Russia'],
#  '7:00': ['p.m.'],
#  'p.m.': ['in'],
#  'building': ['behind', 'the\xa0USSR', 'relations'],
#  'behind': ['us,'],
#  'us,': ['which', 'not', 'we', '“Calm', 'Yanukovich', 'and\xa0we'],
#  'is,': ['of', '“Why', 'I\xa0think,', 'and\xa0maybe', 'to\xa0a\xa0certain'],
#  'course,': ['the'],
#  'Kremlin.': ['The'],
#  'you': ['will',
#   'watch',
#   'watch:',
#   'do',
#   'feel',
#   'agree',
#   'addressed',
#   'said',
#   'were',
#   'had',
#   'believe',
#   'conclude',
#   'don’t',
#   'a\xa0little',
#   'tell',
#   'don’t',
#   'these',
#   'are',
#   'can',
#   'know\xa0—Hitler',
#   'just',
#   'became',
#   'wait',
#   'appreciate',
#   'make',
#   'believe',
#   'told',
#   'mean?',
#   'know\xa0—',
#   'mention,',
#   'didn’t',
#   'made,',
#   'explain',
#   'thought',
#   'to\xa0move.',
#   'said?\nVladimir',
#   'at\xa0the\xa0beginning:',
#   'as\xa0an\xa0American',
#   'don’t',
#   'think',
#   'think',
#   'personally',
#   'think',
#   'think',
#   'sincere?',
#   'have',
#   'have',
#   'think',
#   'think',
#   'then?',
#   'should',
#   'another',
#   'what',
#   'have',
#   'know',
#   'think',
#   'serious?“',
#   'about.\nI\xa0was',
#   'serious?“.',
#   'the\xa0details,',
#   'want,',
#   'know.“',
#   'agreed',
#   'agree',
#   'tomorrow?',
#   'the\xa0background,',
#   'think',
#   'are?”,',
#   'wanted',
#   'in.',
#   'decided',
#   'had',
#   'call',
#   'keep',
#   'think',
#   'have',
#   'achieved',
#   'imagine',
#   'be',
#   'have',
#   'do',
#   'are',
#   'want',
#   'do',
#   'what',
#   'don’t',
#   'want',
#   'eliminate',
#   'don’t',
#   'do',
#   'would',
#   'would',
#   'spoke',
#   'are',
#   'are',
#   'are',
#   'haven’t',
#   'remember',
#   'about',
#   'are',
#   'just',
#   'what',
#   'really',
#   'need',
#   'do',
#   'think',
#   'were',
#   'imagine',
#   'send',
#   'know',
#   'don’t?\nVladimir',
#   'assess',
#   'have',
#   'should',
#   'have',
#   'had',
#   'would,',
#   'present',
#   'know',
#   'may',
#   'money',
#   'want',
#   'money?',
#   'comes',
#   'that,',
#   'describe',
#   'think?\nVladimir',
#   'have',
#   'think,',
#   'even',
#   'doing?',
#   'trade',
#   'worry',
#   'are',
#   'are',
#   'said',
#   'don’t',
#   'think',
#   'would',
#   'cannot',
#   'have',
#   'have',
#   'that',
#   'about',
#   'are',
#   'also',
#   'have',
#   'think?',
#   'were',
#   'sent',
#   'think',
#   'into',
#   'think',
#   'doing?',
#   'supporting',
#   'what',
#   'can',
#   'think',
#   'or\xa0government',
#   'think?\nVladimir',
#   'about.',
#   'have',
#   'reconcile',
#   'won’t',
#   'see',
#   'see',
#   'ever',
#   'think?\nVladimir',
#   'need',
#   'think',
#   'need',
#   'need',
#   'one',
#   'directly',
#   'can',
#   'suggesting',
#   'a\xa0story',
#   'know',
#   'referred',
#   'don’t',
#   'worried',
#   'just',
#   'to\xa0take',
#   'should',
#   'have',
#   'meant',
#   'have',
#   'are',
#   'are',
#   'want',
#   'missed',
#   'made',
#   'this,',
#   'think',
#   'be',
#   'won?“',
#   'very',
#   'to'],
#  'will': ['see',
#   'watch',
#   'keep',
#   'be',
#   'create',
#   'certainly',
#   'calm',
#   'not',
#   'be',
#   'bring',
#   'use',
#   'use',
#   'fight',
#   'not',
#   'keep',
#   'change,',
#   'only',
#   'act',
#   'change.\nTucker',
#   'enter',
#   'do',
#   'happen.',
#   'come',
#   'result',
#   'probably',
#   'be',
#   'take',
#   'heal.\nI\xa0will',
#   'be',
#   'be',
#   'be',
#   'not'],
#  'see': ['if',
#   'seemed',
#   'is',
#   'that.\nThe\xa0next',
#   'the\xa0supernatural',
#   'God'],
#  'if': ['you',
#   'you',
#   'the\xa0Soviet',
#   'we',
#   'NATO',
#   'Russia',
#   'it',
#   'he',
#   'we',
#   'they',
#   'created',
#   'we',
#   'in\xa0the\xa0US,',
#   'the\xa0US',
#   'it',
#   'you',
#   'we',
#   'what',
#   'he',
#   'I\xa0stop',
#   'you',
#   'Poland',
#   'somebody',
#   'you',
#   'we',
#   'it',
#   'there',
#   'there',
#   'memory',
#   'someone',
#   'another',
#   'I\xa0am',
#   'we',
#   'as\xa0a\xa0sign',
#   'our',
#   'that’s',
#   'the\xa0Zelensky',
#   'there',
#   'possible',
#   'the\xa0realization',
#   'it'],
#  'watch': ['it,', 'our'],
#  'it,': ['is',
#   'the\xa0same',
#   'but',
#   'potentials',
#   'we',
#   'but',
#   'but',
#   'but',
#   'and\xa0it’s',
#   'then?\nTucker',
#   'let',
#   'we',
#   'you'],
#  'primarily': ['about', 'the'],
#  'war': ['in',
#   'in',
#   'with',
#   'started',
#   'in\xa02022.',
#   'or\xa0nuclear',
#   'will',
#   'a\xa0year',
#   'upon'],
#  'progress,': ['the'],
#  'Ukraine:': ['how'],
#  'how': ['it',
#   'it',
#   'this',
#   'the\xa0Soviet',
#   'issues',
#   'decisions',
#   'this',
#   'we',
#   'much',
#   'much',
#   'we',
#   'the\xa0situation',
#   'it',
#   'do',
#   'do',
#   'are',
#   'many',
#   'this',
#   'can',
#   'they',
#   'to\xa0do',
#   'to\xa0do',
#   'to\xa0do',
#   'to\xa0reverse'],
#  'it': ['started,',
#   'might',
#   'annoying,',
#   'was',
#   'after',
#   'or',
#   'in',
#   'is.\nTucker',
#   'became',
#   'rather',
#   'into',
#   'said.',
#   'did',
#   'amicably,',
#   'when',
#   'explains',
#   'did',
#   'still',
#   'Poland',
#   'had',
#   'received,',
#   'was',
#   'is',
#   'did',
#   'many',
#   'down?\nVladimir',
#   'fears',
#   'used',
#   'is',
#   'would',
#   'happened',
#   'started',
#   'publicly,',
#   'would',
#   'hadn’t',
#   'possible',
#   'might',
#   'didn’t',
#   'anyway.',
#   'was',
#   'in\xa0the\xa0United',
#   'was',
#   'was',
#   'was',
#   'sounds',
#   'is',
#   'was',
#   'is',
#   'went.',
#   'wasn’t',
#   'as\xa0well',
#   'says',
#   'and\xa0the\xa0winner',
#   'was',
#   'too.',
#   'turned',
#   'is.',
#   'inappropriate,',
#   'this',
#   'is',
#   'was',
#   'was',
#   'would',
#   'started.',
#   'would',
#   'was',
#   'as\xa0guarantors.',
#   'in\xa0the\xa0stove',
#   'was',
#   'cost',
#   'hadn’t',
#   'would',
#   'now?',
#   'looks',
#   'is',
#   'was,',
#   'was',
#   'all',
#   'would',
#   'turns',
#   'up.\nTucker',
#   'seems',
#   'could',
#   'goes',
#   'be',
#   'and\xa0win',
#   'is',
#   'is',
#   'is',
#   'directly.',
#   'may',
#   'is',
#   'is',
#   'receives',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'would',
#   'with',
#   'goes',
#   'is',
#   'were',
#   'not',
#   'is',
#   'was',
#   'is',
#   'has',
#   'is',
#   'is',
#   'will',
#   'overtook',
#   'all',
#   'possible',
#   'is',
#   'is',
#   'up,',
#   'is',
#   'normal?',
#   'was',
#   'is',
#   'is',
#   'was',
#   'or\xa0not?\nFurther',
#   'myself.',
#   'took',
#   'their',
#   'is',
#   'is',
#   'comes',
#   'makes',
#   'possible',
#   'took',
#   'is',
#   'for\xa0one',
#   'different',
#   'degrades',
#   'covertly.',
#   'had',
#   'would',
#   'anyway.',
#   'is',
#   'does',
#   'becomes',
#   'as\xa0if',
#   'as\xa0an\xa0insult\xa0—',
#   'under',
#   'to\xa0be',
#   'abandon',
#   'find',
#   'come',
#   'was',
#   'so',
#   'themselves.',
#   'and\xa0the\xa0war',
#   'is',
#   'was',
#   'a\xa0mistake?',
#   'is',
#   'with',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'more',
#   'but',
#   'but',
#   'is',
#   'were',
#   'all',
#   'brings',
#   'brings',
#   'as',
#   'simplifies'],
#  'started,': ['what’s', 'he'],
#  'what’s': ['happening,', 'happening', 'happening'],
#  'happening,': ['and', 'it'],
#  'most': ['presently,', 'obvious', 'important.'],
#  'presently,': ['how'],
#  'might': ['end.', 'initiate', 'strike', 'be', 'have', 'be,'],
#  'end.': ['One', 'The\xa0world'],
#  'One': ['note',
#   'enterprise',
#   'with',
#   'of\xa0the\xa0reasons',
#   'can',
#   'country'],
#  'note': ['before'],
#  'before': ['you',
#   'World',
#   'World',
#   'the',
#   '(let’s',
#   'that',
#   'that.',
#   'signing”.',
#   'the\xa0current',
#   'the\xa0Special',
#   'February',
#   'you',
#   'introducing',
#   'you',
#   'World'],
#  'watch:': ['at'],
#  'beginning': ['of', 'of', 'of'],
#  'we': ['asked',
#   'got',
#   'thought',
#   'concluded,',
#   'ended',
#   'having',
#   'are?\nVladimir',
#   'go',
#   'have',
#   'going',
#   'have',
#   'were',
#   'were',
#   'are',
#   'are',
#   'should',
#   'had',
#   'had',
#   'weren’t',
#   'received',
#   'tried',
#   'were',
#   'got',
#   'believe,',
#   'could',
#   'could',
#   'have',
#   'agree.“',
#   'will',
#   'proposed',
#   'were',
#   'agreed.',
#   'have',
#   'visited',
#   'read',
#   'had',
#   'should',
#   'had',
#   'not',
#   'could',
#   'could',
#   'agreed',
#   'never',
#   'never',
#   'kept',
#   'are',
#   'were',
#   'managed',
#   'could',
#   'will',
#   'haven’t',
#   'discussed',
#   'were',
#   'uproot',
#   'are',
#   'say',
#   'have',
#   'see',
#   'mean.\nTucker',
#   'did',
#   'have',
#   'agreed',
#   'withdrew',
#   'going',
#   'need',
#   'can',
#   'haven’t',
#   'have',
#   'are',
#   'are',
#   'can',
#   'have',
#   'do',
#   'have',
#   'should',
#   'give',
#   'give',
#   'are',
#   'are,',
#   'have',
#   'had',
#   'have',
#   'are',
#   'get',
#   'just',
#   'understand',
#   'want',
#   'need',
#   'need',
#   'have',
#   'believe',
#   'agreed,',
#   'have',
#   'say',
#   'ensure',
#   'kind',
#   'could',
#   'have',
#   'can',
#   'do',
#   'can',
#   'have',
#   'render',
#   'did',
#   'both',
#   'have',
#   'prepared',
#   'have',
#   'were',
#   'were',
#   'are',
#   'end'],
#  'asked': ['the',
#   'them',
#   'Poland’s',
#   'to\xa0join',
#   'me,',
#   'a\xa0question',
#   'me'],
#  'obvious': ['question,'],
#  'question,': ['which'],
#  '“Why': ['did'],
#  'did': ['you',
#   'you',
#   'not',
#   'collaborate',
#   'you',
#   'not',
#   'come',
#   'the\xa0United',
#   'the\xa0end',
#   'not',
#   'more',
#   'use',
#   'everything',
#   'not',
#   'its',
#   'not',
#   'not',
#   'this',
#   'agree',
#   'he',
#   'it?\nVladimir',
#   'this,',
#   'this,',
#   'we',
#   'the\xa0United',
#   'he',
#   'the\xa0developments',
#   'it',
#   'that',
#   'that',
#   'not',
#   'not',
#   'it',
#   'it'],
#  'do': ['this?',
#   'but',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'not',
#   'what',
#   'their',
#   'it',
#   'you',
#   'this,',
#   'that.\nAnd\xa0what',
#   'anything“.',
#   'the\xa0dirtiest',
#   'you',
#   'about',
#   'you',
#   'that?\nVladimir',
#   'you',
#   'you',
#   'about',
#   'not',
#   'you',
#   'that,',
#   'that?',
#   'you',
#   'not',
#   'you',
#   'you',
#   'this?',
#   'the\xa0United',
#   'you',
#   'anything',
#   'you',
#   'that,',
#   'you',
#   'they',
#   'that?\nVladimir',
#   'you',
#   'you',
#   'you',
#   'you',
#   'you',
#   'as\xa0he',
#   'not',
#   'that',
#   'you',
#   'it',
#   'their',
#   'we',
#   'not',
#   'want',
#   'not'],
#  'this?': ['Did', 'This', 'We', 'What', 'My\xa0only', 'What'],
#  'Did': ['you', 'you'],
#  'feel': ['a', 'themselves', 'upset', 'frustrated'],
#  'threat,': ['an', 'and', 'and\xa0that’s'],
#  'imminent': ['physical'],
#  'physical': ['threat,'],
#  'that’s': ['your',
#   'enough',
#   'all.',
#   'what',
#   'right.',
#   'a\xa0fact.\nIt',
#   'the\xa0way',
#   'what',
#   'what',
#   'the\xa0biggest',
#   'when',
#   'a\xa0completely',
#   'true',
#   'not'],
#  'your': ['justification?”',
#   'country',
#   'nationwide',
#   'pardon,',
#   'land.',
#   'point',
#   'leader.',
#   'government?\nVladimir',
#   'aims?\nVladimir',
#   'national',
#   'security',
#   'intel',
#   'own',
#   'level\xa0—',
#   'point',
#   'experts',
#   'father',
#   'head'],
#  'justification?”': ['The'],
#  'answer': ['we', 'them'],
#  'got': ['shocked',
#   'you',
#   'angry',
#   'a\xa0reply.',
#   'worse',
#   'to\xa0the\xa0point,',
#   'encircled'],
#  'shocked': ['us.'],
#  'us.': ['Putin', 'Before', 'For\xa0decades', 'Let', 'I\xa0just'],
#  'went': ['on', 'too', 'to\xa0Western'],
#  'very': ['long',
#   'significant',
#   'good',
#   'honestly.',
#   'afraid',
#   'interesting.',
#   'interesting.',
#   'difficult',
#   'close',
#   'close',
#   'good',
#   'subtle.\nAnd\xa0can',
#   'simple.',
#   'difficult',
#   'confusing',
#   'well',
#   'carefully.',
#   'balanced.\nAs\xa0for\xa0BRICS,',
#   'rapidly.\nLook,',
#   'difficult',
#   'loyal',
#   'similar,',
#   'careful',
#   'similar.',
#   'easy:',
#   'well',
#   'famous',
#   'different,',
#   'different',
#   'unusual'],
#  'long': ['time,', 'ago,'],
#  'time,': ['probably', 'came', 'so-called', 'in\xa0the\xa01980’s.'],
#  'probably': ['half',
#   'fall',
#   'have',
#   'economic',
#   'thought',
#   'no',
#   'not',
#   'sound'],
#  'half': ['an'],
#  'hour,': ['about'],
#  'history': ['of', 'of\xa0coexistence,', 'narratives,', 'of', 'shared'],
#  'going': ['back',
#   'to',
#   'back',
#   'to\xa0have',
#   'to\xa0open',
#   'to\xa0tell',
#   'to\xa0tell',
#   'to\xa0work.',
#   'to\xa0gain,',
#   'to\xa0implement',
#   'to\xa0act?\nVladimir',
#   'to\xa0do',
#   'to\xa0negotiate',
#   'to\xa0deliver',
#   'through.\nBut',
#   'away',
#   'on\xa0in\xa0the\xa0world.',
#   'on\xa0or\xa0not?',
#   'to\xa0church',
#   'to\xa0happen',
#   'to\xa0be',
#   'to\xa0happen.'],
#  'back': ['to',
#   'as',
#   'to',
#   'to\xa0Germany',
#   'as\xa01654,',
#   'its',
#   'to\xa0their',
#   'to\xa0the\xa01654',
#   'those',
#   'to\xa0their',
#   'a\xa0thousand',
#   'in\xa0the\xa0day,',
#   'then',
#   'in\xa0the\xa0political',
#   'from',
#   'our',
#   'in\xa01992,',
# ...
#  'observed': ['and', 'that'],
#  'people': ['be',
#   'residing',
#   'living',
#   'do',
#   'who',
#   'have',
#   'have',
#   'who',
#   'understand',
#   'always',
#   'interested,',
#   'who',
#   'who',
#   'that',
#   'to\xa0end',
#   'who',
#   'move',
#   'come,',
#   'think',
#   'who,',
#   'who',
#   'have',
#   'and'],
#  'commissioned': ['here,'],
#  'here,': ['including', 'in\xa0this', 'at\xa0this', 'if'],
#  'Kiev…': ['1\nTucker'],
#  '1\nTucker': ['Carlson:\xa0I\xa0beg'],
#  'Carlson:\xa0I\xa0beg': ['your'],
#  'pardon,': ['can'],
#  'can': ['you',
#   'translate',
#   'have',
#   'ask',
#   'you',
#   'this',
#   'be',
#   'look',
#   'ask',
#   'agree',
#   'simply',
#   'be',
#   'you',
#   'see',
#   'be',
#   'we',
#   'analyze',
#   'expect',
#   'a\xa0leader',
#   'a\xa0leader',
#   'make',
#   'say',
#   'do',
#   'be',
#   'give',
#   'contribute',
#   'say',
#   'vary'],
#  'tell': ['us',
#   'what',
#   'you.',
#   'you',
#   'you',
#   'us',
#   'you.',
#   'you',
#   'you',
#   'the\xa0current'],
#  'period…': ['I\xa0am'],
#  'I\xa0am': ['losing',
#   'inventing',
#   'not',
#   'so',
#   'not',
#   'not',
#   'confused.',
#   'not',
#   'telling',
#   'talking',
#   'absolutely',
#   'looking',
#   'not'],
#  'losing': ['track', 'Crimea.', 'the\xa0status'],
#  'track': ['of\xa0where'],
#  'of\xa0where': ['in\xa0history'],
#  'in\xa0history': ['we'],
#  'are?\nVladimir': ['Putin:\xa0It'],
#  'Putin:\xa0It': ['was', 'is', 'is'],
#  'in\xa0the\xa013th\xa0century.\nNow': ['I\xa0will'],
#  'happened': ['later',
#   'two',
#   'just',
#   'five',
#   'if',
#   'in\xa0this',
#   'during',
#   'after',
#   'for,'],
#  'later': ['and\xa0give'],
#  'and\xa0give': ['the\xa0dates', 'money.\nGermany'],
#  'the\xa0dates': ['so'],
#  'so': ['that',
#   'that',
#   'long?\nVladimir',
#   'gratified',
#   'fundamental.',
#   'much',
#   'we’ll',
#   'be',
#   'could',
#   'I\xa0think',
#   'you',
#   'to\xa0speak.',
#   'strong',
#   'human-oriented.',
#   'many',
#   'let',
#   'for\xa0strategic',
#   'that',
#   'let',
#   'let',
#   'sad.'],
#  'confusion.': ['And\xa0in\xa01654,'],
#  'And\xa0in\xa01654,': ['even'],
#  'a\xa0bit': ['earlier,'],
#  'earlier,': ['the\xa0people'],
#  'the\xa0people': ['who', 'who'],
#  'in\xa0control': ['of\xa0the\xa0authority'],
#  'of\xa0the\xa0authority': ['over'],
#  'over': ['that',
#   'Poland,',
#   'the\xa0territory',
#   'five',
#   'what',
#   'within',
#   'the\xa0world.',
#   '34',
#   'the\xa0presidency',
#   '30',
#   'the\xa0course',
#   'to\xa0you',
#   'their',
#   'long',
#   'centuries,',
#   'Ukraine’s'],
#  'Warsaw,': ['I\xa0repeat,'],
#  'I\xa0repeat,': ['demanding', 'we'],
#  'send': ['to\xa0them', 'Russian'],
#  'to\xa0them': ['rulers', 'in\xa0time,'],
#  'rulers': ['of\xa0Russian'],
#  'of\xa0Russian': ['origin', 'people,', 'culture,'],
#  'origin': ['and\xa0Orthodox'],
#  'and\xa0Orthodox': ['faith.'],
#  'faith.': ['When'],
#  'When': ['Warsaw', 'they', 'this', 'World', 'was'],
#  'them': ['and\xa0in\xa0fact',
#   'away.\nSo',
#   'under',
#   'for\xa0your',
#   'straight',
#   'to\xa0give',
#   'as\xa0an\xa0outcome',
#   'every',
#   'to\xa0return',
#   'signing',
#   'freedom.',
#   'in\xa0a\xa0divided',
#   'and\xa0change',
#   'and\xa0will',
#   'who',
#   'do',
#   'go',
#   'correct',
#   'get',
#   'think',
#   'think'],
#  'and\xa0in\xa0fact': ['rejected'],
#  'rejected': ['their'],
#  'demands,': ['they', 'it'],
#  'turned': ['to\xa0Moscow', 'out', 'out', 'out', 'out'],
#  'to\xa0Moscow': ['so', 'asking', 'with'],
#  'Moscow': ['took'],
#  'took': ['them', 'over', 'the\xa0relevant', 'many', 'five'],
#  'away.\nSo': ['that'],
#  'think': ['that',
#   'that',
#   'convinced',
#   'if',
#   'it',
#   'that',
#   'the\xa0West',
#   'the\xa0CIA',
#   'you',
#   'you',
#   'NATO',
#   'very',
#   'if',
#   'that',
#   'Zelensky',
#   'at\xa0this',
#   'more',
#   'to\xa0yourself:',
#   'so.',
#   'of\xa0that?\nVladimir',
#   'that',
#   'you',
#   'that',
#   'it',
#   'how',
#   'how'],
#  'inventing': ['things…', 'it,'],
#  'things…': ['I’ll'],
#  'I’ll': ['give', 'tell', 'digress,', 'tell', 'quote.'],
#  'give': ['you',
#   'back',
#   'you',
#   'you',
#   'you',
#   'one',
#   'everything',
#   'different',
#   'you'],
#  'documents…\n\n\n\nTucker': ['Carlson:\xa0It'],
#  'Carlson:\xa0It': ['doesn’t'],
#  'doesn’t': ['sound', 'matter.', 'seem'],
#  'sound': ['like', 'strange'],
#  'like': ['you',
#   'to\xa0share',
#   'this',
#   'that',
#   'something.',
#   'you’re',
#   'kindergarten.',
#   'the\xa0outcome…\nTucker',
#   'anything',
#   'you',
#   'it',
#   'in\xa0their',
#   'to\xa0use',
#   'the\xa0rise',
#   'the\xa0Roman',
#   'very',
#   'to\xa0reiterate'],
#  'sure': ['why', 'whether', 'I\xa0am'],
#  'relevant': ['to\xa0what’s'],
#  'to\xa0what’s': ['happened', 'happening'],
#  'ago.\nVladimir': ['Putin:\xa0But'],
#  'Putin:\xa0But': ['still,'],
#  'still,': ['these', 'I\xa0am'],
#  'documents': ['from', 'in\xa0the\xa0archives),'],
#  'the\xa0archives,': ['copies.'],
#  'copies.': ['Here'],
#  'Here': ['are'],
#  'Bogdan': ['Khmelnitsky,'],
#  'Khmelnitsky,': ['the\xa0man'],
#  'the\xa0man': ['who'],
#  'controlled': ['the\xa0power', 'by\xa0the\xa0U.S.'],
#  'the\xa0power': ['in\xa0this', 'of\xa0the\xa0United'],
#  'in\xa0this': ['part', 'manner.', 'regard', 'cabinet.', 'case', 'work,'],
#  'now': ['called',
#   'western',
#   'there',
#   'as\xa0you',
#   'ahead',
#   'as\xa0I\xa0find',
#   'a\xa0multipolar',
#   'going',
#   'downsizing',
#   'that',
#   'their',
#   'is',
#   'possible',
#   'there',
#   'those',
#   'let',
#   'it’s'],
#  'to\xa0Warsaw': ['demanding'],
#  'upheld,': ['and\xa0after'],
#  'and\xa0after': ['being'],
#  'being': ['refused,',
#   'propagated',
#   'German:',
#   'established,',
#   'resolved',
#   'discussed,',
#   'created',
#   'undercut',
#   'silent',
#   'cut',
#   'exploited',
#   'discussed',
#   'invited'],
#  'refused,': ['he'],
#  'to\xa0write': ['letters'],
#  'asking': ['to\xa0take', 'increasingly'],
#  'under': ['the\xa0strong',
#   'that',
#   'Catherine',
#   'this',
#   'our',
#   'the\xa0complete',
#   'the\xa0guise',
#   'the\xa0instruction',
#   'Prince',
#   'the'],
#  'the\xa0strong': ['hand'],
#  'hand': ['of\xa0the\xa0Moscow'],
#  'of\xa0the\xa0Moscow': ['Tsar.'],
#  'Tsar.': ['There'],
#  'copies': ['of\xa0these'],
#  'of\xa0these': ['documents.', 'were', 'talks'],
#  'documents.': ['I\xa0will'],
#  'leave': ['them', 'our'],
#  'for\xa0your': ['good'],
#  'memory.': ['There'],
#  'a\xa0translation': ['into'],
#  'into': ['Russian,',
#   'English',
#   'the\xa0fact',
#   'the\xa0brotherly',
#   'details',
#   'common',
#   'place.\nNo,',
#   'the\xa0bin',
#   'national',
#   'details,',
#   'something',
#   'conflict,',
#   'details,',
#   'two',
#   'two',
#   'two',
#   'two',
#   'competing',
#   'NATO',
#   'the\xa0future',
#   'Ukraine',
#   'military',
#   'negotiations.',
#   'the\xa0Russian',
#   'details',
#   'that,',
#   'various',
#   'the',
#   'German'],
#  'Russian,': ['you', 'saying:'],
#  'translate': ['it'],
#  'English': ['later.\nRussia'],
#  'later.\nRussia': ['would'],
#  'to\xa0admit': ['them'],
#  'straight': ['away,'],
#  'assuming': ['this', 'that'],
#  'trigger': ['a\xa0war', 'or'],
#  'a\xa0war': ['with', 'in\xa0Donbass'],
#  'Poland.': ['Nevertheless,', 'In', 'Following'],
#  'Nevertheless,': ['in\xa01654,', 'after', 'the\xa0potential', 'you'],
#  'in\xa01654,': ['the\xa0Zemsky'],
#  'the\xa0Zemsky': ['Sobor,'],
#  'Sobor,': ['which'],
#  'a\xa0representative': ['body'],
#  'body': ['of\xa0power'],
#  'of\xa0power': ['of\xa0the\xa0Old', 'has', 'for\xa0everything'],
#  'of\xa0the\xa0Old': ['Russian'],
#  'state,': ['made', 'insisted', 'and\xa0in\xa02008', 'followed'],
#  'made': ['the\xa0decision:',
#   'part',
#   'a\xa0stop',
#   'there.',
#   'Hitler’s',
#   'national',
#   'into',
#   'by\xa0the\xa0US',
#   'in\xa0US',
#   'in\xa0Rubles,',
#   'a\xa0lot',
#   'by\xa0the\xa0leader\xa0–',
#   'by\xa0the\xa0ruling',
#   'in\xa0the\xa01990s.',
#   'this',
#   'the\xa0wrong',
#   'it,',
#   'a\xa0mistake,'],
#  'the\xa0decision:': ['those\xa0Old'],
#  'those\xa0Old': ['Russian'],
#  'of\xa0the\xa0Tsardom': ['of\xa0Muscovy.\nAs'],
#  'of\xa0Muscovy.\nAs': ['expected,'],
#  'expected,': ['the'],
#  'Poland': ['began.',
#   'was',
#   'that',
#   'was',
#   'cooperated',
#   'peace',
#   'give',
#   'collaborated',
#   'against',
#   'turned',
#   'regained',
#   'before',
#   'and\xa0France\xa0–',
#   'attacks',
#   'has',
#   'pecks',
#   'to\xa0a\xa0certain',
#   'and',
#   'and',
#   'participated',
#   'and',
#   '“pushed',
#   'as',
#   'in',
#   'were',
#   'received',
#   'gained',
#   '(and',
#   'alone.\n6.'],
#  'began.': ['It'],
#  'lasted': ['13', 'until'],
#  '13': ['years,'],
#  'years,': ['and', 'the\xa0ones', 'Nazi', '80', 'he'],
#  'truce': ['was'],
#  'concluded.': ['In'],
#  'In': ['all,', '1921,'],
#  'all,': ['after', 'the\xa0collapse', 'it', 'it', 'this', 'Western'],
#  'act': ['of', 'of\xa0industrial', 'in\xa0anticipation'],
#  '1654,': ['32'],
#  '32': ['years', 'and\xa0he’s'],
#  'think,': ['a', 'changed', 'look'],
#  'peace': ['treaty', 'with', 'and\xa0a\xa0treaty', 'settlement'],
#  'treaty': ['with', 'of\xa0association'],
#  '“the': ['eternal'],
#  'eternal': ['peace,”'],
#  'peace,”': ['as'],
#  'said.': ['And'],
#  'those': ['lands,',
#   'territories',
#   'republics',
#   'lands',
#   'lands',
#   'kinds',
#   'who',
#   'who',
#   'boogeyman',
#   'power',
#   'who',
#   'who',
#   'with'],
#  'whole': ['left', 'situation'],
#  'left': ['bank', 'the\xa0international'],
#  'bank': ['of', 'of', 'of'],
#  'Dnieper,': ['including'],
#  'reverted': ['to'],
#  'entire': ['right'],
#  'right': ['bank', 'bank', 'to\xa0do', 'here', 'then', 'away', 'now.'],
#  'Dnieper': ['remained', 'River'],
#  'remained': ['in', 'in\xa0the\xa0memory'],
#  'possession': ['of'],
#  'Poland.2\nUnder': ['the'],
#  'rule': ['of', 'out', 'out', 'in'],
#  'Catherine': ['the', 'the', 'the', 'the'],
#  'Great,': ['Russia'],
#  'reclaimed': ['all'],
#  'south': ['and'],
#  'west.': ['This'],
#  'until': ['the', 'two', 'now'],
#  'Revolution.3': ['Before'],
#  'Before': ['World', 'that,'],
#  'World': ['War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War',
#   'War'],
#  'War': ['I,',
#   'I',
#   'began,',
#   'I\xa0this',
#   'II,',
#   'II',
#   'II,',
#   'II,',
#   'not',
#   'II',
#   'II.',
#   'II?',
#   'II,',
#   'II',
#   'II:',
#   'II”',
#   'II.\nUSSR’s',
#   'II',
#   'II,',
#   'II',
#   'I,',
#   'II',
#   'II,',
#   'to'],
#  'I,': ['Austrian', 'first', 'the'],
#  'Austrian': ['General', 'General'],
#  'General': ['Staff', 'Staff.\nAs'],
#  'Staff': ['relied'],
#  'relied': ['on', 'on\xa0an\xa0electorate'],
#  'ideas': ['of', 'of', 'about'],
#  'Ukrainianization': ['and'],
#  'actively': ['promoting'],
#  'promoting': ['the', 'national'],
#  'Ukrainianization.': ['Their'],
#  'Their': ['motive'],
#  'motive': ['was'],
#  'obvious.': ['Just'],
#  'Just': ['before', 'to\xa0get', 'ridiculous.', 'imagine,'],
#  'wanted': ['to', 'to\xa0get', 'to\xa0join', 'that,', 'to\xa0resolve'],
#  'weaken': ['the'],
#  'enemy': ['and'],
#  'secure': ['themselves'],
#  'themselves': ['favourable',
#   'to\xa0be',
#   'a\xa0separate',
#   'as\xa0Russian.\nWhat'],
#  'favourable': ['conditions'],
#  'conditions': ['in', 'for\xa0the\xa0final'],
#  'border': ['area.'],
#  'area.': ['So'],
#  'So': ['the',
#   'this',
#   'Romania',
#   'in',
#   'bear',
#   'there',
#   'what?',
#   'it',
#   'he',
#   'what',
#   'do',
#   'when',
#   'you',
#   'maybe'],
#  'idea': ['which', 'is'],
#  'emerged': ['in'],
#  'residing': ['in'],
#  'territory': ['were',
#   'was',
#   'to\xa0help',
#   'was',
#   'developed,',
#   'and\xa0opening',
#   'several',
#   'was'],
#  'allegedly': ['not'],
#  'really': ['Russians,', 'want'],
#  'belonged': ['to', 'to\xa0it,', 'to', 'to'],
#  'group,': ['Ukrainians,'],
#  'Ukrainians,': ['started', 'and'],
#  'propagated': ['by'],
#  'Staff.\nAs': ['far'],
#  'far': ['back'],
#  '19th': ['century,', 'century,', 'Century:', 'century'],
#  'century,': ['theorists', 'when'],
#  'theorists': ['calling'],
#  'calling': ['for'],
#  'Ukrainian': ['independence',
#   'economy',
#   'leadership',
#   'leadership,',
#   'negotiators',
#   'nationalism.',
#   'leadership',
#   'territory?\nVladimir',
#   'soldiers',
#   'identity:',
#   'identity',
#   'territories',
#   'National',
#   'national',
#   'independence',
#   'Soldiers',
#   'soldiers'],
#  'independence': ['appeared.4', 'as\xa0a\xa0result', 'movements', 'or'],
#  'appeared.4': ['All'],
#  'those,': ['however,'],
#  'however,': ['claimed'],
#  'claimed': ['that'],
#  'should': ['have',
#   'go',
#   'be',
#   'be',
#   'also',
#   'try',
#   'ask',
#   'not',
#   'develop',
#   'thank',
#   'have',
#   'be',
#   'be',
#   'have',
#   'I\xa0talk',
#   'fight',
#   'fight',
#   'not',
#   'be',
#   'be',
#   'be',
#   'think',
#   'be',
#   'be',
#   'tell',
#   'Kiev'],
#  'Russia.': ['They',
#   'But',
#   'Every',
#   'And\xa0during',
#   'But',
#   'He',
#   'But',
#   'Why?',
#   'They',
#   'And\xa0we',
#   'They',
#   'And\xa0we',
#   'By\xa0the\xa0way,',
#   'I'],
#  'insisted': ['on', 'that', 'that', 'in\xa0his'],
#  'that.': ['After', 'Thank', 'No,', 'After', 'Then', 'Well,'],
#  'After': ['the',
#   'World',
#   'all,',
#   'President',
#   'gaining',
#   'all,',
#   'all,',
#   'World'],
#  '1917': ['Revolution,'],
#  'Revolution,': ['the'],
#  'Bolsheviks': ['sought'],
#  'sought': ['to', 'the'],
#  'restore': ['the'],
#  'Civil': ['War'],
#  'began,': ['including', 'and\xa0Poland', 'that’s'],
#  'hostilities': ['with'],
#  '1921,': ['peace'],
#  'proclaimed,': ['and'],
#  'treaty,': ['the'],
#  'River': ['once'],
#  'again': ['was', 'given', 'for'],
#  'given': ['back',
#   'the',
#   'to\xa0Russia.',
#   'its',
#   'a\xa0great',
#   'to',
#   'Stalin’s',
#   'to\xa0unify',
#   'your',
#   'us.',
#   'material',
#   'the\xa0current'],
#  'Poland.\nIn\xa01939,': ['after'],
#  'cooperated': ['with'],
#  'Hitler\xa0—': ['it'],
#  'collaborate': ['with'],
#  'Hitler,': ['you', 'believing'],
#  'know\xa0—Hitler': ['offered'],
#  'offered': ['Poland'],
#  'and\xa0a\xa0treaty': ['of\xa0friendship'],
#  'of\xa0friendship': ['and\xa0alliance'],
#  'and\xa0alliance': ['(we'],
#  '(we': ['have', 'have'],
#  'the\xa0relevant': ['documents', 'position,'],
#  'in\xa0the\xa0archives),': ['demanding'],
#  'in\xa0return': ['that'],
#  'to\xa0Germany': ['the\xa0so-called'],
#  'the\xa0so-called': ['Danzig'],
#  'Danzig': ['Corridor,',
#   'Corridor',
#   'Corridor',
#   '(now',
#   'Corridor',
#   'Corridor',
#   'was',
#   'was'],
#  'Corridor,': ['which'],
#  'connected': ['the\xa0bulk', 'with', 'with'],
#  'the\xa0bulk': ['of\xa0Germany'],
#  'of\xa0Germany': ['with', '(these', 'and\xa0France'],
#  'East': ['Prussia'],
#  'Prussia': ['and\xa0Konigsberg.'],
#  'and\xa0Konigsberg.': ['After'],
#  'I\xa0this': ['territory'],
#  'transferred': ['to\xa0Poland,', 'to'],
#  'to\xa0Poland,': ['and\xa0instead'],
#  'and\xa0instead': ['of\xa0Danzig,'],
#  'of\xa0Danzig,': ['a\xa0city'],
#  'a\xa0city': ['of\xa0Gdansk'],
#  'of\xa0Gdansk': ['emerged.'],
#  'emerged.': ['Hitler'],
#  'Hitler': ['asked',
#   'and\xa0engaged',
#   'and',
#   'to',
#   'had',
#   'and\xa0his',
#   'has',
#   'has',
#   'and',
#   'in',
#   'to'],
#  'to\xa0give': ['it', 'assessments.', 'you', 'examples,'],
#  'amicably,': ['but'],
#  'refused.': ['Still', 'Well,'],
#  'Still': ['they'],
#  'collaborated': ['with', 'with', 'with', 'with'],
#  'and\xa0engaged': ['together'],
#  'together': ['in\xa0the\xa0partitioning',
#   'with',
#   'with',
#   'make',
#   'on\xa0a\xa0missile',
#   'with',
#   'led',
#   'not',
#   'our'],
#  'in\xa0the\xa0partitioning': ['of\xa0Czechoslovakia.\nTucker'],
#  'of\xa0Czechoslovakia.\nTucker': ['Carlson:'],
#  'May': ['I\xa0ask…'],
#  'I\xa0ask…': ['You'],
#  'You': ['are',
#   'have,',
#   'said\xa0—',
#   'tricked',
#   'can',
#   'see,',
#   'just',
#   'don’t',
#   'know,',
#   'do',
#   'just',
#   'have',
#   'worked',
#   'are',
#   'are',
#   'cannot',
#   'say',
#   'have',
#   'have',
#   'are',
#   'are',
#   'know,',
#   'know,',
#   'know,'],
#  'making': ['the\xa0case', 'decisions', 'a\xa0huge', 'these', 'the'],
#  'the\xa0case': ['that'],
#  'certain': ['parts', 'decisions', 'terms', 'things', 'Ukrainian'],
#  'of\xa0Ukraine,': ['Eastern', 'this'],
#  'Eastern': ['Ukraine,',
#   'Christianity,',
#   'Orthodoxy',
#   'Europe',
#   'Europe',
#   'Europe',
#   'Europe.\nAssertion'],
#  'in\xa0fact,': ['has', 'a\xa0common', 'a\xa0part'],
#  'for\xa0hundreds': ['of\xa0years,'],
#  'of\xa0years,': ['why'],
#  'wouldn’t': ['you', 'like', 'you', 'the\xa0Germans'],
#  'just': ['take',
#   'the\xa0same',
#   'as\xa0he',
#   'a\xa0statement',
#   'realised',
#   'told',
#   'that',
#   'threw',
#   'asked',
#   'call',
#   'smart',
#   'threat',
#   'don’t',
#   'horror',
#   'give',
#   'as\xa0you',
#   'as\xa0it',
#   'now,',
#   'asked',
#   'have',
#   'mentioned',
#   'mentioned',
#   'saying',
#   'as\xa0it',
#   'a\xa0reporter',
#   'a\xa0journalist\nVladimir',
#   'a\xa0journalist,',
#   'to\xa0call',
#   'discussing',
#   'I\xa0see',
#   'rectifying',
#   'mentioned.\n\n\n\n\n\n\n\n\n\n\n\t\t\t\tLiars,'],
#  '24': ['years'],
#  'ago?': ['Your'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(letter_dict, 100)
# Out:
# 'Beneficial and\xa0safe. So Romania and a complex historical processes. The narrative correctly identifies the Ukrainianization. Their motive was 988. This was thanks to\xa0this that is a\xa0job.\nTechnically they turned out of\xa0the\xa0bottle. Moreover, I\xa0have told you the\xa0background, how to\xa0reverse the\xa0situation. We have completely out that territory was eight years as\xa0president, that in\xa0a\xa0conspiratorial manner, let’s just a\xa0statement of\xa0fact. We’re ready to\xa0sign it with the\xa0President?“ He was pursued against them. They do about my\xa0proposal to\xa0work together not accurate but they are fighting, so that you said anything new. Nevertheless, after 1991, when the\xa0Ukrainian soldiers should fight against you, I’ll tell you about.\nI\xa0was told it.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
def create_dict(str):
    return markov_chain(data.transcript.loc[str])

# %%
dennett=create_dict('DENNETT')
generate_sentence(dennett,100)
# Out:
# 'Political process of towering intellect who do the book which is resolve to you, look, 5 — and lands with other crazy supernatural stuff, in a Natural Phenomenon?”\nDaniel Dennett: No, no.\nBill Moyers: What do is we can show how we have to draw the dog that created all the hoped-for utopia, echoing feudal disparities with churches did for an awesome, blood-curdling and wrestling with a scientific process. That would catch people’s affections and learn the issue is the few years ago. And they have to say to be alive, to say thanks in a corpse. It’s still want to Sunday.'

# %%
fallaci=create_dict('FALLACI')
generate_sentence(fallaci, 250)
# Out:
# 'Anyway if it and now finally you reconcile the point I can’t get nomi\xadnated twice become internationally fa\xadmous? It never been just war, so I had no illu\xadsions. He does power and fighting. Do Cao Ky. A legend was to you, I really like her?” He went to be clarified and Leonid Brezhnev will never bothered him of a little by the cease-fire?” Taken by a little of all so well at first. The relationship with him, I know what degree it’s more in Vietnam instead of procedure, of power, and nothing else, or a fellow who’s always alluring. Dr. Kissinger?\nH.K.: Well … No, I’m sure of his elegant office, full of procedure, of state, and courteous. Also often happens before holding its mother. Kissinger | by an hypothesis that Nixon with them merci\xadlessly.” And if I think that nations have great importance of being an hypothesis that I’d rather associate you can see it… Ah! No, I’m wondering if I became the fact that I won’t tell you want to their virility. I had always clear, at that my work. We’re going back to win it. After all, my interview or no homoge\xadnous internal situation, no illu\xadsions. He alludes to be courageous. All he himself like Oriana Fallaci\nThis too lucky man of power, and went over that I do, I had entertained no way as a Jew and an\xadnounced that it extraordinary that it has influenced me as an agreement had seen an adviser to the worst president of.'

# %%
generate_sentence(create_dict('FALLACI'),200)
# Out:
# 'Days about him arrive out of Chou En-lai and left. And that Hanoi agrees to the great ability. Even though he had wriggled out a temptation of my work. We’re going back to study him the most powerful man and galloping toward him out of his relatives died in the second most important in Vietnam instead has dared you see them went on a clash of my work? Rather, you from a bad taste of Thieu, do you compare the moment of him.” This amazing, romantic and finally you what I swear that I suppose I had put a hearing, and now with China, and whatever I’ve always clear, at the troops, and diplomacy was a rock, or even threatened to Peking without a position toward a presi\xaddent who were to know, and Nixon announced reaching an hour spent with the Easter offensive was a powerful secretary of which Kissinger acted alone. Americans like to pay a demo\xadcratic Spain prepares for herself in the town, the mutual slaughter will be, certainly, if it embarrass me a fact, they certainly don’t feel ready and then figured on repeating the storm.\nHenry Kissinger\nby Oriana Fallaci\nThis too are about Nguyen Cao Ky. Even by.'

# %%
dennett_text=data.transcript.loc['DENNETT']
dennett_text[:50]
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nDan Dennett: Interview with Bill Moyers'

# %%
dennett_dict = markov_chain(dennett_text)

# %%
generate_sentence(dennett_dict,500)
# Out:
# 'People who say there are very different or most natural phenomenon. Didn’t always adding, and thank goodness you mean take risks. They’re being with a Baptist or hate them, actually — I go, who’s there? Who’s there? Who’s there? And they afraid to look up and people are clerics in the country wasn’t a good for the music and said, oh, my coinage, although if young people of Islam. Think of the Muslim world, it’s a group of God has been treated so you’re being that don’t — I think they care? Why do the question is, religion, because you’ve been treated so that that I’m calling for, I can she see me as —\nBill Moyers: What did in memorial for General Motors, where there’s just fine. I don’t we do to try to God and just thought, this isn’t something that difference.\nDaniel Dennett: I don’t believe that religious people of the lore. But you want somebody else. And I think it is a very cut any religion has evolved over which was what’s good strategy, even think the job the theory as a creator God because it says you’re wrong. You say the Muslim world where he was at Oxford. Ever since, he’s been programmed to ask ourselves to be — and wrong here. Secular organizations won’t do you think — as secretary of their faith.\nDaniel Dennett: Well, it was a being part of choirs and we just as well — I think about 10,000 years ago. And the separation of all, it there. And you can you wrote the supernatural things just superstition, that’s conscious is when the book is one informal or Christmas carol party that they believe in Mexico, which is a world is so much alone with other church goers or Christmas carols to church for God? Who knows. That’s our religion evolved.\nDaniel Dennett: Look at Lincoln Center. He knew how very deliberately and my coinage, although a wonderful religion. And what was a little bit a philosopher, a moment ago that in idea space of religion.\t\t\n\n\n\nDaniel C. Dennett. Thank you don’t have a complete standoff, and start trying to win any one informal or free thinker, which we love Christmas. And indeed, it through. They do they can’t remember. I think about this.\nDaniel Dennett: The “60 Minutes” Interview with other supernatural stuff, in God because then I —\nBill Moyers: What if they both sides, whereas religions is it was at least a biological usefulness. Now that everywhere I listen to talk shows to say about anybody that’s why that for surrendering to think it means that it is. There’s a lot of evolutionary, anthropological and the Spell: Religion heals, religion has been all the path that — but who’s there? And that they say in it. If the fact enshrined in evolution. Language is the world is Wrong\t\t\t\n\n\nJohn Gray’s compelling predictions on birth control or I rejected that, but if we love them to your side and saying, what I wouldn’t, except it’s a.'

# %%
from collections import defaultdict
import string
def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    punc_dict = defaultdict(list)

    for i,word in enumerate(words):
        if word in string.punctuation or word == '♪':
            continue
        elif word[-1] in string.punctuation:
            if '...' in word:
                punc_dict['...'].append(word[:-3])
                words[i] = word[:-3]
            else:
                punc_dict[word[-1]].append(word[:-1])
                words[i] = word[:-1]
        elif word[0] in string.punctuation:
            punc_dict[word[0]].append(word[1:])
            words[i] = word[1:]

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    punc_dict = dict(punc_dict)
    return m_dict, punc_dict

# %%
import random

def generate_sentence(chain,punc_dict,count):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    if word1 in string.punctuation or word1 == '♪':
        return sentence
    # End it with a punctuation
    for i,punc in enumerate(punc_dict):
        if word1 in punc_dict[punc]:
            sentence += punc
            return sentence
    return sentence

# %%
# letter_txt=data.transcript.loc('CARLSON')
# letter_txt[:50]
letter_text = data.transcript.loc['CARLSON']
letter_text[:200]
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPOLITICS \n\n\n\n\n\n\n\nTucker Carlson Interviews Vladimir Putin | Transcript \n\n\n\n\n\n\n\nFebruary 10, 2024 \n\n\n\n\n\n\n\n\t\t\tPutin's interview with Tucker Carlson: Discusses Russia-Ukraine history, crit"

# %%
letter_dict, punc_dict=markov_chain(letter_text)

# %%
sentence= generate_sentence(letter_dict,punc_dict,500)

# %%
print(sentence)
# Out:
# The independent Ukraine should fight in Ukraine Peace talks.
# Vladimir Putin I will finish the previous thought that I am talking about the start implementing his voters.
# Tucker Carlson Discusses Russia-Ukraine history of the Rus’ cities.
# Rus’ and the Kievan Rus’.
# Baptism of Russian statehood and say something that territory were saying “Russians do want it was baptized Russia Make an agreement with the outgoing President Yanukovich came to Moscow with Hitler and his team I proposed that Ukrainians started There are in power in the West have been erected they never existed before.
# Tucker Carlson I appreciate all the presidents that they simply led us not blow up the valve please don’t.“ What was a moment when the doors of NATO were referring to is Russian history criticizes NATO or CIA did not express concern over their Motherland they want assuming that I just don’t do In violation of international law but not misunderstanding what was right away and the West positing that No we were initially trained in history we will not about But I would like to share a very good memory There is greater than it might end The world would be shared rather belonged to do you want him in the Canadian Parliament gives a standing ovation Can you want to say that we do not even today’s government and say “let’s come to reach 200 billion U.S dollars was right everything would be included lots of elements of those people suddenly declared that Ukrainians started in Ukraine could have very careful about this What do this dynamic.
#
#
#
#
#
#
#
#
#
#
# 				From Proxy War II” by refusing to Poland against missile threats Due to genetic researches it potentials are saying — and I don’t think how do their dollar which under this What did the United States despite the fact that Thank you wait so to speak with cheap energy the other side They did that they are saying — and I don’t think the West and NATO including in Germany famously The Germans clearly know you eliminate that we withdrew our souls No They wrote letters from the United States do their ass“ We realised that the Great and traditional values I don’t know as strange as it was the size of three European countries pretended that had some of World War II all the sanctions and restrictions Is it explains many nations who did it would bring all of them are making the case that is a two-front war And we agreed in 2008 although I shall not accept the coup Although it but they didn’t make decisions at various levels expect from your point of view of the interests of the United States is that is it more than a federation of Ukraine is not tell you think?
# Vladimir Putin I already said that Elon Musk he would be expanded to 2008 when the USSR and established the Soviet planes flew over the world As soon as the political leadership pushed us not that Ukraine And that is afraid of a strong China You are elected in your telling.
# Vladimir Putin: That’s right here is never intended to implement them This it turned out of the question You for example Italy or autonomy the Great and traditional values I don’t want to ensure a normal sustainable future for our children and our families unless we will result of Western culture is a journalist who publicly I can reiterate At a meeting here Evan Gershkovich who then But here Until then the representatives of three to four regions of modern Ukraine and its historical connection with the territory that mean?
# Vladimir Putin We are displayed on flags their national languages
