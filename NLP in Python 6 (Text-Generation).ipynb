# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                            transcript  \
# LETTERKENNY         Letterkenny concludes with its series finale, ...
# MASTERS OF THE AIR  “Masters of the Air,” a 2024 American war dram...
# MONSIEUR SPADE      Monsieur Spade\nSeason 1 Episode 2\nEpisode Ti...
# SLOW HORSES         Episode Title: Footprints\nSeries: Slow Horses...
# TRUE DETECTIVE      True Detective\nSeason 4 Episode 3\nEpisode Ti...
#
#                                                   full_name
# LETTERKENNY            LETTERKENNY – S12E06 – OVER AND OUT
# MASTERS OF THE AIR  MASTERS OF THE AIR – S01E01 – PART ONE
# MONSIEUR SPADE                  MONSIEUR SPADE – EPISODE 2
# SLOW HORSES               SLOW HORSES – S03E06 – FOOTPRINTS
# TRUE DETECTIVE             TRUE DETECTIVE – S04E03 – PART 3

# %%
# Extract only Ali Wong's text
letter_text = data.transcript.loc['LETTERKENNY']
letter_text[:200]
# Out:
# 'Letterkenny concludes with its series finale, Season 12 Episode 6, “Over and Out,” delivering a heartfelt and humorous farewell. The episode is filled with fun callbacks and a sense of contentment amo'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
letter_dict = markov_chain(letter_text)
letter_dict
# Out:
# {'Letterkenny': ['concludes',
#   'and',
#   'universe.',
#   'Legionnaires',
#   'has',
#   'consists'],
#  'concludes': ['with'],
#  'with': ['its',
#   'fun',
#   'its',
#   'a',
#   'a',
#   'everyone',
#   'emotional',
#   'Dan',
#   'pelicans?',
#   'science.',
#   'Peregrines.',
#   'pelicans.',
#   'no',
#   'you',
#   'that?',
#   'a',
#   'this',
#   'his',
#   'a'],
#  'its': ['series', 'quirky', 'characters,', 'inhabitants', 'dick', 'pace.'],
#  'series': ['finale,', 'ends,'],
#  'finale,': ['Season'],
#  'Season': ['12'],
#  '12': ['Episode'],
#  'Episode': ['6,', 'aired', '4'],
#  '6,': ['“Over'],
#  '“Over': ['and'],
#  'and': ['Out,”',
#   'humorous',
#   'a',
#   'unique',
#   'bird',
#   'a',
#   'an',
#   'eventually',
#   'reminiscing.',
#   'closes',
#   'presumably',
#   'fans,',
#   'its',
#   'the',
#   'your',
#   'ekspecially',
#   'mouses',
#   'all',
#   'hicks',
#   'Fun-Dip',
#   'a',
#   'a',
#   'think',
#   'the',
#   'a',
#   'a',
#   'conquered',
#   'rice,',
#   'it',
#   'a',
#   'Break',
#   'hockey',
#   'as',
#   'gentlemen,',
#   'out.',
#   'faces',
#   'Navarro',
#   'a',
#   'Spade’s',
#   'media’s'],
#  'Out,”': ['delivering'],
#  'delivering': ['a'],
#  'a': ['heartfelt',
#   'sense',
#   'nostalgic',
#   'surprise',
#   'rave,',
#   'significant',
#   'joyous',
#   'love',
#   'legacy',
#   'quarter-page',
#   'page.',
#   'kids!”',
#   'kid?',
#   'calf',
#   'baby',
#   'baby',
#   'big',
#   'birds,',
#   'penguin?',
#   'turkey?',
#   'birds',
#   'good',
#   'common',
#   'Pere-grin.',
#   'barrels.',
#   'cashews.',
#   'Stork',
#   'baby?',
#   'degen',
#   'pretty',
#   'lot',
#   'pretty',
#   'bum',
#   'fucked',
#   'hard',
#   'waste.”',
#   'rope.',
#   'Jolly',
#   'honey',
#   'look',
#   'child?',
#   'light',
#   'cookie',
#   'sour',
#   'sun',
#   'coke.',
#   'camera',
#   'camera',
#   'bit',
#   'dream.',
#   'successful',
#   'bit?',
#   'wee',
#   'rave',
#   'ton',
#   'choice',
#   'genre',
#   'rave',
#   'dirty',
#   'little',
#   'special',
#   'token',
#   'local',
#   'Texas',
#   'prominent',
#   'surly',
#   'mystery',
#   'dark',
#   'key',
#   'web',
#   'week'],
#  'heartfelt': ['and'],
#  'humorous': ['farewell.'],
#  'farewell.': ['The'],
#  'The': ['episode',
#   'finale',
#   'episode',
#   'Skids',
#   'rave',
#   'episode',
#   'finale',
#   'show',
#   'creator’s',
#   'falconer',
#   'Peregrine',
#   'Bubblicious',
#   'Cheeto',
#   'gummy',
#   'Peanut',
#   'Hottest',
#   'Hottest',
#   'over',
#   'most',
#   'site',
#   'skids.',
#   'hicks.',
#   'fuckin’'],
#  'episode': ['is', 'starts', 'subtly'],
#  'is': ['filled',
#   'exactly',
#   'absurd.',
#   'about',
#   'the',
#   'maybes',
#   'us.',
#   'the',
#   'degens.',
#   'this.',
#   'a',
#   'precisely',
#   'wrong',
#   'when',
#   'work!',
#   'the'],
#  'filled': ['with'],
#  'fun': ['callbacks', 'to', 'to'],
#  'callbacks': ['and'],
#  'sense': ['of', 'to'],
#  'of': ['contentment',
#   'small-town',
#   'the',
#   'Letterkenny',
#   'laughter,',
#   'knowing',
#   'the',
#   'the',
#   'a',
#   '“Stork',
#   'those',
#   'calling',
#   '24',
#   'any',
#   'prey.',
#   'about',
#   'feet',
#   'gopher,',
#   'his',
#   'some',
#   'them',
#   '’em.',
#   'staying',
#   'each',
#   'our',
#   'our',
#   'it,',
#   'our',
#   'gas',
#   'the',
#   'amateurs',
#   'them',
#   'the',
#   'sense',
#   'music',
#   'family!',
#   'friendship!',
#   'community!',
#   'having',
#   'hicks,',
#   'yous',
#   'course!',
#   'our',
#   'a',
#   'a',
#   '“Monsieur',
#   'intrigue',
#   'the',
#   'Usher’'],
#  'contentment': ['among'],
#  'among': ['the', 'the', 'us,'],
#  'the': ['residents,',
#   'notion',
#   'series’',
#   'show’s',
#   'previous',
#   'gang',
#   'Degens',
#   'never-ending',
#   'evolving',
#   'various',
#   'Ag',
#   'community',
#   'series',
#   'spirit',
#   'comfort',
#   'characters’',
#   'audience',
#   'Letterkenny',
#   'newspaper',
#   'other',
#   'Storks',
#   'Letterkennys',
#   'Banner',
#   'Stork',
#   'Banner',
#   'title',
#   'Blue',
#   'news.',
#   'baby,',
#   'acts',
#   'time.',
#   'Blue-Footed',
#   'baby',
#   'thrust',
#   'bird',
#   'air',
#   'falconers',
#   'land,',
#   'world’s',
#   'Peregrine',
#   'jump',
#   'thing.',
#   'shits',
#   'last',
#   'shits',
#   'distance)',
#   'years.',
#   'best,',
#   'times',
#   'times',
#   'womb.',
#   'mirror',
#   'Kit-Kat',
#   'Foot?',
#   'fuck',
#   'dogs.',
#   'maple',
#   'best',
#   'years',
#   'hard',
#   'sexiest',
#   'truck',
#   'whole',
#   'greatest',
#   'kids',
#   'Bronx',
#   'platform',
#   'fartist.',
#   'Gastro',
#   'superior',
#   'chamber',
#   'way',
#   'Ag',
#   'Ag',
#   'Ag',
#   'spirit',
#   'spirit',
#   'spirit',
#   'Ag',
#   'point',
#   'Ag',
#   'attitude,',
#   'word',
#   'record,',
#   'Lord.',
#   'birthday',
#   'House',
#   'privacy',
#   'Loft.',
#   'best'],
#  'residents,': ['embracing'],
#  'embracing': ['the'],
#  'notion': ['that'],
#  'that': ['sometimes',
#   'while',
#   'stork',
#   'cock',
#   'choice',
#   'nut',
#   'bum',
#   'world',
#   'it',
#   'dream.',
#   'not'],
#  'sometimes': ['being'],
#  'being': ['where', 'cute,'],
#  'where': ['you', 'you', 'the'],
#  'you': ['are',
#   'need',
#   'lookin’',
#   'call',
#   'could',
#   'don’t',
#   'there,',
#   'thinks',
#   'wanna',
#   'know.',
#   'got',
#   'jumpin’',
#   'in',
#   'say,',
#   'dropped',
#   'as',
#   'make',
#   'breakfast.',
#   'are',
#   'are',
#   'then.',
#   'behind.',
#   'back',
#   'say',
#   'sure?',
#   'sure?',
#   'guys',
#   'talking',
#   'help',
#   'believe',
#   'we',
#   'want',
#   'are',
#   'for',
#   'ready…'],
#  'are': ['is',
#   'you',
#   'powerful.',
#   'ya',
#   'not',
#   'not',
#   'suggesting.',
#   'proposing.',
#   'not…',
#   'not',
#   'we?',
#   'we…',
#   'sure.',
#   'for',
#   'fine.',
#   'you',
#   'we?',
#   'we',
#   'going',
#   'going',
#   'you',
#   'marked'],
#  'exactly': ['where', 'what'],
#  'need': ['to', 'two', 'some', 'science'],
#  'to': ['be.',
#   'organize',
#   'cater',
#   'all.',
#   'treasured',
#   'Keeso’s',
#   '“Letterkenny,”',
#   'fans',
#   'Dary.',
#   'have',
#   'reads.',
#   'go,',
#   'read',
#   'go…',
#   'see',
#   'see',
#   'this',
#   'carry',
#   'get',
#   'have',
#   'cooperate',
#   'about',
#   'come',
#   'land',
#   'at',
#   'pull',
#   'carry',
#   'falconers',
#   'get',
#   'do',
#   'think',
#   'say',
#   'balance',
#   'beats',
#   'take',
#   'the',
#   'think',
#   'take',
#   'want',
#   'point',
#   'point',
#   'our',
#   'limit',
#   'a',
#   'cordially',
#   'us?',
#   'come,',
#   'put',
#   'put',
#   'our',
#   'debut',
#   'Georgia',
#   'appear',
#   'your'],
#  'be.': ['The'],
#  'finale': ['reflects', 'serves'],
#  'reflects': ['the'],
#  'series’': ['spirit'],
#  'spirit': ['of', 'of', 'of', 'of', 'of'],
#  'small-town': ['life,', 'drug'],
#  'life,': ['with'],
#  'quirky': ['characters'],
#  'characters': ['and'],
#  'unique': ['humor.'],
#  'humor.': ['The'],
#  'starts': ['with'],
#  'nostalgic': ['cold'],
#  'cold': ['open'],
#  'open': ['discussing', 'up'],
#  'discussing': ['local'],
#  'local': ['gossip', 'favourite.'],
#  'gossip': ['and'],
#  'bird': ['misconceptions,', 'it’s', 'of', 'to'],
#  'misconceptions,': ['capturing'],
#  'capturing': ['the'],
#  'show’s': ['typical'],
#  'typical': ['banter.'],
#  'banter.': ['It'],
#  'It': ['then', 'sure', 'used', 'wasn’t'],
#  'then': ['revisits'],
#  'revisits': ['the'],
#  'previous': ['night’s'],
#  'night’s': ['events,'],
#  'events,': ['where'],
#  'gang': ['successfully'],
#  'successfully': ['thwarts'],
#  'thwarts': ['the'],
#  'Degens': ['with'],
#  'surprise': ['attack,'],
#  'attack,': ['hinting'],
#  'hinting': ['at'],
#  'at': ['the',
#   'the',
#   'me',
#   '‘er.',
#   'any',
#   'least',
#   'you,',
#   'you.',
#   'yourself.',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the'],
#  'never-ending': ['battle'],
#  'battle': ['between'],
#  'between': ['them.'],
#  'them.': ['Amidst', 'What'],
#  'Amidst': ['this,'],
#  'this,': ['we', 'good'],
#  'we': ['see',
#   'had',
#   'are',
#   'forget,',
#   'know',
#   'can',
#   'only',
#   'had',
#   'were',
#   'gonna'],
#  'see': ['dream', 'important', 'which', 'if'],
#  'dream': ['sequences,'],
#  'sequences,': ['plans'],
#  'plans': ['for'],
#  'for': ['reviving',
#   'more',
#   'the',
#   'the',
#   'us…',
#   'you.',
#   'cats',
#   'someone',
#   'not?',
#   'iFartRadio.',
#   'agricultural',
#   'a',
#   'rave',
#   'everyone.',
#   'coming',
#   '“Sun'],
#  'reviving': ['past'],
#  'past': ['endeavors'],
#  'endeavors': ['like', 'have'],
#  'like': ['Fartbook',
#   'the',
#   'full',
#   'Stevie',
#   'Fruit',
#   'something',
#   'all',
#   'it',
#   'the',
#   'one',
#   'to'],
#  'Fartbook': ['and', 'from', 'with', 'walked'],
#  'rave,': ['and', 'considering'],
#  'an': ['acknowledgment', 'eighth', '8-pound', 'adult.'],
#  'acknowledgment': ['of'],
#  'evolving': ['relationships'],
#  'relationships': ['among', 'and'],
#  'various': ['groups'],
#  'groups': ['in'],
#  'in': ['Letterkenny.',
#   'a',
#   'the',
#   'a',
#   'ten',
#   'eight.',
#   'eight!',
#   'sixteen.',
#   'the',
#   'the',
#   'the',
#   'a',
#   'silently',
#   'moderation.',
#   'a',
#   '‘The'],
#  'Letterkenny.': ['The'],
#  'Skids': ['attempt'],
#  'attempt': ['to'],
#  'organize': ['another'],
#  'another': ['rave,'],
#  'considering': ['everyone’s'],
#  'everyone’s': ['music'],
#  'music': ['tastes,', 'we', 'they', 'stops)'],
#  'tastes,': ['and'],
#  'eventually': ['decide'],
#  'decide': ['to'],
#  'cater': ['to'],
#  'all.': ['The'],
#  'rave': ['at', 'at', 'at', 'at', 'at', 'music,'],
#  'Ag': ['Hall', 'Hall!', 'Hall?', 'Hall', 'Hall!', 'Hall'],
#  'Hall': ['becomes', 'to', 'if'],
#  'becomes': ['a'],
#  'significant': ['event,'],
#  'event,': ['bringing'],
#  'bringing': ['together'],
#  'together': ['the'],
#  'community': ['in'],
#  'joyous': ['celebration,'],
#  'celebration,': ['with'],
#  'everyone': ['dancing'],
#  'dancing': ['and'],
#  'reminiscing.': ['The'],
#  'subtly': ['explores'],
#  'explores': ['potential'],
#  'potential': ['future'],
#  'future': ['relationships', 'projects,'],
#  'closes': ['with'],
#  'emotional': ['tributes'],
#  'tributes': ['to'],
#  'treasured': ['town'],
#  'town': ['locations'],
#  'locations': ['and'],
#  'presumably': ['to'],
#  'Keeso’s': ['real-life'],
#  'real-life': ['dog,'],
#  'dog,': ['Gus.'],
#  'Gus.': ['The'],
#  'serves': ['as'],
#  'as': ['a', 'the', 'along', 'there’s', 'a', 'an', 'what', 'what', 'a'],
#  'love': ['letter', 'country', 'country'],
#  'letter': ['to'],
#  '“Letterkenny,”': ['its'],
#  'characters,': ['and'],
#  'fans,': ['promising'],
#  'promising': ['that'],
#  'while': ['the'],
#  'ends,': ['the'],
#  'inhabitants': ['endures.'],
#  'endures.': ['The'],
#  'show': ['leaves'],
#  'leaves': ['a'],
#  'legacy': ['of'],
#  'laughter,': ['witty'],
#  'witty': ['dialogue,'],
#  'dialogue,': ['and'],
#  'comfort': ['of'],
#  'knowing': ['the'],
#  'characters’': ['lives'],
#  'lives': ['continue'],
#  'continue': ['even'],
#  'even': ['as', 'native', 'know', 'a'],
#  'audience': ['says'],
#  'says': ['goodbye.', 'we’re'],
#  'goodbye.': ['The'],
#  'creator’s': ['future'],
#  'projects,': ['including'],
#  'including': ['“Shoresy,”'],
#  '“Shoresy,”': ['offer'],
#  'offer': ['some'],
#  'some': ['solace', 'crazy', 'degens.', 'trouble'],
#  'solace': ['to'],
#  'fans': ['eager'],
#  'eager': ['for'],
#  'more': ['of', 'than', 'degens', 'times', 'respect', 'victim'],
#  'universe.': ['Episode'],
#  'aired': ['December'],
#  'December': ['26,'],
#  '26,': ['2023'],
#  '2023': ['*'],
#  '*': ['*', '*', '♪', 'Name*'],
#  '♪': ['You', 'Sun', '\n\n\n\n\n\n'],
#  'You': ['and',
#   'think?',
#   'could',
#   'need',
#   'have',
#   'look',
#   'like',
#   'can',
#   'owe',
#   'took',
#   'stole',
#   'sure?',
#   'don’t'],
#  'your': ['pals',
#   'side.',
#   'pals',
#   'names',
#   'mom',
#   'tongue',
#   'fucking',
#   'e-mail\n\n',
#   'inbox!'],
#  'pals': ['were', 'to'],
#  'were': ['talkin’', 'done'],
#  'talkin’': ['about'],
#  'about': ['the',
#   '10',
#   'if',
#   '240',
#   '390s',
#   '3500',
#   '3500.',
#   '2cock',
#   'the',
#   '20%'],
#  'newspaper': ['the'],
#  'other': ['day…', 'big'],
#  'day…': ['They’re'],
#  'They’re': ['cutting'],
#  'cutting': ['the', 'the…', 'the…'],
#  'Storks': ['Reports', 'aren’t'],
#  'Reports': ['from'],
#  'from': ['the', 'us,', 'you,', 'the'],
#  'Letterkennys': ['Banners.'],
#  'Banners.': ['Good.'],
#  'Good.': ['Pardon?', 'Pardon?'],
#  'Pardon?': ['I', 'I', '(mumbling)'],
#  'I': ['said',
#   'heard',
#   'said,',
#   'was',
#   'coulds.',
#   'gets',
#   'get',
#   'open',
#   'think…',
#   'was',
#   'think',
#   'do',
#   'was',
#   'was',
#   'think',
#   'don’t',
#   'don’t',
#   'have',
#   'fucked',
#   'cooked',
#   'found',
#   'stole',
#   'could',
#   'feel',
#   'came',
#   'dareth.',
#   'dareth',
#   'think…',
#   'like',
#   'just',
#   'told',
#   'accept'],
#  'said': ['they’re'],
#  'they’re': ['cutting', 'cutting'],
#  'the…': ['I', 'I', '(both):'],
#  'heard': ['ya.'],
#  'ya.': ['Oh.', 'Everything'],
#  'Oh.': ['Good.', 'It’s', 'Thank', 'And'],
#  'said,': ['they’re'],
#  'was': ['talking',
#   'just',
#   'thinking,',
#   'confusing',
#   'moving',
#   'leaving',
#   'holding',
#   'no',
#   'all'],
#  'talking': ['to', 'to'],
#  'Dary.': ['Oh.', 'World’s'],
#  'It’s': ['inappropriate', 'no', 'fun', 'fair'],
#  'inappropriate': ['to'],
#  'have': ['a',
#   'it',
#   'carried',
#   'to',
#   'a',
#   'all',
#   'to',
#   'our',
#   'a',
#   'failed',
#   'flopped',
#   'a',
#   'a'],
#  'quarter-page': ['column'],
#  'column': ['on'],
#  'on': ['page',
#   'page',
#   'page',
#   'your',
#   'planet',
#   'at',
#   'that',
#   'them.',
#   'fires?',
#   'the…',
#   'the',
#   'our',
#   'your',
#   'his'],
#  'page': ['two', 'two.', 'two.'],
#  'two': ['of', 'like', 'dozen', 'in'],
#  'Banner': ['always', 'to', 'Blitz'],
#  'always': ['announcing', 'gonna', 'gonna', 'gonna', 'gonna'],
#  'announcing': ['which'],
#  'which': ['nut', 'nut'],
#  'nut': ['sacks', 'sacks', 'sacks’', 'cheerio.'],
#  'sacks': ['had', 'had'],
#  'had': ['kids.', 'a', 'kids,', 'more', 'the', 'become', 'sex'],
#  'kids.': ['It’s'],
#  'no': ['more', 'Stork', 'shirt', 'talent', 'longer', 'OnlyFarts.', 'one'],
#  'than': ['an', 'pillaging', 'there', 'I', 'Fartbook?'],
#  'eighth': ['of'],
#  'page.': ['That’s'],
#  'That’s': ['splittin’', 'fast.', 'exactly', 'probably', 'the', 'a'],
#  'splittin’': ['hairs.'],
#  'hairs.': ['And'],
#  'And': ['it’s',
#   'secondly,',
#   'getting',
#   'rather',
#   'all',
#   'most',
#   'left',
#   'what',
#   'like',
#   'we',
#   'Christians.',
#   'you'],
#  'it’s': ['only',
#   'fun',
#   'a',
#   'an',
#   'pretty',
#   'called',
#   'a',
#   'a',
#   'time',
#   '’cause…'],
#  'only': ['just', 'like'],
#  'just': ['often',
#   'gimme',
#   'said…',
#   'ballparkin’',
#   'the',
#   'wanna',
#   'take',
#   'one',
#   'don’t',
#   'have'],
#  'often': ['on'],
#  'two.': ['I’ds', 'I'],
#  'I’ds': ['have'],
#  'it': ['right',
#   'the',
#   'could',
#   'all',
#   'to',
#   'all!',
#   'from',
#   'better',
#   'was',
#   'takes',
#   'had',
#   'was',
#   'a',
#   'makes',
#   'out.',
#   'on',
#   'on'],
#  'right': ['up', 'now.', 'on'],
#  'up': ['fronts', 'the', 'people.', 'your', 'nose.', 'a'],
#  'fronts': ['if'],
#  'if': ['I', 'they', 'it’s', 'you', 'it’s', 'it’s', 'Fruity', 'no'],
#  'coulds.': ['Fucking'],
#  'Fucking': ['‘eh.'],
#  '‘eh.': ['Why'],
#  'Why': ['do', 'are'],
#  'do': ['yous', 'toos.', 'degens', 'you', 'this,', 'you', 'ya.'],
#  'yous': ['two', 'confusing', 'knows', 'ever', 'could', 'gonna'],
#  'Stork': ['Report', 'has', 'to'],
#  'Report': ['so'],
#  'so': ['much?', 'long', 'what', 'you', 'epically', 'heroically', 'iToots'],
#  'much?': ['It’s'],
#  'reads.': ['I'],
#  'gets': ['to'],
#  'go,': ['“Oh,'],
#  '“Oh,': ['they'],
#  'they': ['hads', 'had', 'calls', 'needs', 'won’t', 'will'],
#  'hads': ['a'],
#  'kids!”': ['No,'],
#  'No,': ['it’s', 'Roald.'],
#  'read': ['because'],
#  'because': ['I'],
#  'get': ['to', 'falconed', 'the', 'the', 'a', 'the', 'the'],
#  'go…': ['Oh,'],
#  'Oh,': ['they'],
#  'kid?': ['Should'],
#  'Should': ['be'],
#  'be': ['all',
#   'more',
#   'required',
#   'naive',
#   'degens.',
#   'goods',
#   'good',
#   'really',
#   'great',
#   'no',
#   'published.'],
#  'all': ['business',
#   'the',
#   'sort',
#   'that',
#   'sorta',
#   'that,',
#   'the',
#   'the',
#   'up.”',
#   'time,',
#   'Fartune',
#   'for',
#   'the'],
#  'business': ['on'],
#  'important': ['current'],
#  'current': ['events.'],
#  'events.': ['Like'],
#  'Like': ['police'],
#  'police': ['briefs'],
#  'briefs': ['or'],
#  'or': ['a', 'Commanchero’s', 'takes.', 'all', 'not?'],
#  'calf': ['auction,'],
#  'auction,': ['or'],
#  'Commanchero’s': ['Show’n'],
#  'Show’n': ['Shine.'],
#  'Shine.': ['Letterkenny'],
#  'Legionnaires': ['scores.'],
#  'scores.': ['Banner'],
#  'Blitz': ['with'],
#  'Dan': ['McNee.'],
#  'McNee.': ['Not'],
#  'Not': ['to', 'the', 'even', 'one', 'one', 'one'],
#  'kids,': ['and'],
#  'ekspecially': ['under'],
#  'under': ['the'],
#  'title': ['of'],
#  '“Stork': ['Report”.'],
#  'Report”.': ['Starks'],
#  'Starks': ['retorts.'],
#  'retorts.': ['Firstly,'],
#  'Firstly,': ['no'],
#  'has': ['carried', 'ever', 'some'],
#  'carried': ['a', 'babies'],
#  'baby': ['anywhere.', 'is', 'airborne.'],
#  'anywhere.': ['And', 'Stop'],
#  'secondly,': ['Storks'],
#  'aren’t': ['even'],
#  'native': ['to'],
#  'this': ['area.', 'changes', 'is', 'isn’t', 'guy?'],
#  'area.': ['What'],
#  'What': ['if', 'about', 'if', 'do'],
#  'calls': ['it'],
#  'Blue': ['Herrons', 'Eyed'],
#  'Herrons': ['Reports?'],
#  'Reports?': ['Neither'],
#  'Neither': ['of'],
#  'those': ['birds'],
#  'birds': ['have', 'called', 'to'],
#  'babies': ['anywhere.'],
#  'Stop': ['being'],
#  'cute,': ['just'],
#  'gimme': ['the'],
#  'news.': ['What?'],
#  'What?': ['Hmm?', '‘Cause'],
#  'Hmm?': ['Why'],
#  'lookin’': ['at'],
#  'me': ['so', 'a'],
#  'long': ['for?'],
#  'for?': ['‘Cause'],
#  '‘Cause': ['I', 'agricultural'],
#  'think…': ['what', 'Yeah,'],
#  'what': ['you’ve', 'if', 'I', 'your', 'you', 'you', 'the', 'out?', 'music'],
#  'you’ve': ['just', 'been'],
#  'said…': ['is'],
#  'absurd.': ['So'],
#  'So': ['a', 'if', 'okay,', 'we’re'],
#  '10': ['pound.'],
#  'pound.': ['If'],
#  'If': ['it’s', 'we’re', 'they', 'you'],
#  'big': ['fuckin’', 'fat', 'city', 'city'],
#  'fuckin’': ['fat', 'ballpark!', 'care.', 'drop', 'door’s'],
#  'fat': ['one!', 'fuckin’'],
#  'one!': ['I'],
#  'ballparkin’': ['it.'],
#  'it.': ['Pretty', 'Waynes,', 'Peregrine', 'We…', 'And'],
#  'Pretty': ['big'],
#  'ballpark!': ['Okay'],
#  'Okay': ['so'],
#  '8-pound': ['baby?'],
#  'baby?': ['Who’s', 'He’s'],
#  'Who’s': ['gonna'],
#  'gonna': ['teach', 'be', 'have', 'be', 'be', 'be', 'be', 'be', 'get', 'let'],
#  'teach': ['that'],
#  'stork': ['to'],
#  'carry': ['the', 'a'],
#  'baby,': ['Wayne?'],
#  'Wayne?': ['You?'],
#  'You?': ['I'],
#  'think': ['it’s', 'it', 'it’d', 'this', 'like…', 'I', 'of'],
#  'pretty': ['obvious.', 'good', 'good'],
#  'obvious.': ['You'],
#  'think?': ['I'],
#  'toos.': ['Alright.'],
#  'Alright.': ['Have'],
#  'Have': ['at', 'to'],
#  '‘er.': ['A'],
#  'A': ['falconer.',
#   'falconer?',
#   'peanit.',
#   'falconer',
#   'distraction',
#   'honey',
#   'rave',
#   'little'],
#  'falconer.': ['A'],
#  'falconer?': ['Yeah.'],
#  'Yeah.': ['One'],
#  'One': ['who', 'in', 'of'],
#  'who': ['practices', 'take'],
#  'practices': ['falconing.'],
#  'falconing.': ['Practices'],
#  'Practices': ['what?'],
#  'what?': ['Falconry.', 'A', 'Beats', 'I’ve', 'A'],
#  'Falconry.': ['Falconing'],
#  'Falconing': ['is'],
#  'acts': ['of'],
#  'calling': ['over'],
#  'over': ['a', 'any', 'windows?', 'the', 'saturation'],
#  'birds,': ['Darys.'],
#  'Darys.': ['So', 'How’s'],
#  'call': ['over'],
#  'any': ['bird', 'bird', 'time,'],
#  'called': ['falconing?', 'the', 'Tsalal'],
#  'falconing?': ['Mm-hmm.'],
#  'Mm-hmm.': ['What', 'Mm-hmm.', 'Mm-hmm.', 'Bro.'],
#  'penguin?': ['You'],
#  'could': ['still', 'harness', 'bomb', 'get', 'get', 'match', 'not.', 'run.'],
#  'still': ['falcon'],
#  'falcon': ['it.'],
#  'Waynes,': ['is'],
#  'maybes': ['yous'],
#  'confusing': ['storks’s', 'storks'],
#  'storks’s': ['with'],
#  'pelicans?': ['What'],
#  'turkey?': ['Well,'],
#  'Well,': ['turkeys', 'I’m', 'I', 'it’s', 'I', 'fucking'],
#  'turkeys': ['get'],
#  'falconed': ['all'],
#  'time.': ['Really?'],
#  'Really?': ['There’s'],
#  'There’s': ['probably', 'gonna', 'always', 'always'],
#  'probably': ['someone', 'for'],
#  'someone': ['out', 'to'],
#  'out': ['there', 'to', 'of', 'of', 'of', 'of', 'what'],
#  'there': ['falconing', 'is', 'for', 'for', 'would'],
#  'falconing': ['one', 'a'],
#  'one': ['right',
#   'in',
#   'in',
#   'morning,',
#   'more',
#   'bits.',
#   'drill',
#   'bell',
#   'bell',
#   'drill',
#   'bits.',
#   'bell',
#   'comes'],
#  'now.': ['Did'],
#  'Did': ['yous'],
#  'knows': ['there’s'],
#  'there’s': ['a', 'a', 'enough', 'always'],
#  'Blue-Footed': ['Boobys?'],
#  'Boobys?': ['You’d'],
#  'You’d': ['need', 'have'],
#  'dozen': ['storks'],
#  'storks': ['to', 'with'],
#  'airborne.': ['Plus,'],
#  'Plus,': ['you’d'],
#  'you’d': ['need'],
#  'crazy': ['contraption'],
#  'contraption': ['so'],
#  'harness': ['the'],
#  'thrust': ['of'],
#  '24': ['storks.', 'birds'],
#  'storks.': ['You'],
#  'science': ['on'],
#  'side.': ['You’d'],
#  'good': ['relationship',
#   'buddys?',
#   'buddy.',
#   'guys.',
#   'guys.',
#   'time',
#   'job'],
#  'relationship': ['with'],
#  'science.': ['And'],
#  'getting': ['24'],
#  'cooperate': ['towards'],
#  'towards': ['a'],
#  'common': ['goal?'],
#  'goal?': ['In'],
#  'In': ['today’s', 'the', 'the', 'the'],
#  'today’s': ['social-political'],
#  'social-political': ['climate?'],
#  'climate?': ['Huh.'],
#  'Huh.': ['Forget'],
#  'Forget': ['it.'],
#  'Peregrine': ['falcon.', 'sees', 'to'],
#  'falcon.': ['Or'],
#  'Or': ['Pere-grin.', 'are', 'are'],
#  'Pere-grin.': ['Fastest', 'Only'],
#  'Fastest': ['traveler', 'hunters'],
#  'traveler': ['of'],
#  'prey.': ['Top'],
#  'Top': ['speed'],
#  'speed': ['of'],
#  '240': ['mile', 'mile'],
#  'mile': ['‘n', '‘n'],
#  '‘n': ['hour.', 'hour.'],
#  'hour.': ['Works', 'Eats'],
#  'Works': ['out'],
#  '390s': ['kilometers'],
#  'kilometers': ['per'],
#  'per': ['hours,'],
#  'hours,': ['gives'],
#  'gives': ['or'],
#  'takes.': ['Wow.'],
#  'Wow.': ['That’s', 'Falconers'],
#  'fast.': ['Fastest'],
#  'hunters': ['on'],
#  'planet': ['earths.'],
#  'earths.': ['So'],
#  'okay,': ['Dary,'],
#  'Dary,': ['Dary,', 'okay…'],
#  'okay…': ['Falconers'],
#  'Falconers': ['falconing', 'are'],
#  'Only': ['elite'],
#  'elite': ['falconers'],
#  'falconers': ['fucks', 'arm', 'and'],
#  'fucks': ['with'],
#  'Peregrines.': ['The'],
#  'falconer': ['puts', 'could'],
#  'puts': ['his'],
#  'his': ['arm', 'oysters.', 'land,', 'sweetie', 'Auntie', 'glasses', 'lemon'],
#  'arm': ['out,', 'out.', 'instead.”'],
#  'out,': ['okay?', 'Stewart?'],
#  'okay?': ['Goes…'],
#  'Goes…': ['(whistles)'],
#  '(whistles)': ['Means', 'And'],
#  'Means': ['it’s'],
#  'time': ['for', 'rounding', 'believing'],
#  'come': ['over.', 'out.', 'for', 'for.'],
#  'over.': ['Now'],
#  'Now': ['that', 'he’s'],
#  'cock': ['sucker’s'],
#  'sucker’s': ['dartin’'],
#  'dartin’': ['around'],
#  'around': ['thousands', 'here.'],
#  'thousands': ['of'],
#  'feet': ['in'],
#  'air': ['currentleh.'],
#  'currentleh.': ['I’m'],
#  'I’m': ['thinking', 'going', 'not', 'saying', 'sorry,'],
#  'thinking': ['about'],
#  '3500': ['feets.'],
#  'feets.': ['That’s'],
#  'thinking,': ['about'],
#  '3500.': ['Now'],
#  'he’s': ['got'],
#  'got': ['all', 'you', 'just', 'a'],
#  'sort': ['of'],
#  'gopher,': ['ground'],
#  'ground': ['hog'],
#  'hog': ['and'],
#  'mouses': ['below'],
#  'below': ['he'],
#  'he': ['could', 'wants', 'wants.'],
#  'bomb': ['down'],
#  'down': ['on'],
#  'time,': ['240', 'good', 'Stewart.', 'or', 'is'],
#  'Eats': ['whats'],
#  'whats': ['he'],
#  'wants': ['whens'],
#  'whens': ['he'],
#  'wants.': ['But'],
#  'But': ['despite', 'you', 'do', 'after', 'Roald…'],
#  'despite': ['all'],
#  'choice': ['below,', 'venue'],
#  'below,': ['Dary.'],
#  'World’s': ['his'],
#  'oysters.': ['Unlimited'],
#  'Unlimited': ['options.'],
#  'options.': ['For'],
#  'For': ['snacks.', 'what?', 'sure,'],
#  'snacks.': ['Shootin’'],
#  'Shootin’': ['fish'],
#  'fish': ['in'],
#  'barrels.': ['The'],
#  'sees': ['the'],
#  'out.': ['Hears…', 'Yeah,', 'A', 'Figure', '(rock'],
#  'Hears…': ['(whistles)'],
#  'rather': ['than'],
#  'pillaging': ['the'],
#  'land,': ['his', 'the'],
#  'world’s': ['fastest'],
#  'fastest': ['hunter'],
#  'hunter': ['says,'],
#  'says,': ['“Mm-mm…'],
#  '“Mm-mm…': ['I’m'],
#  'going': ['to', 'back', 'all', 'to', 'to'],
#  'land': ['on'],
#  'sacks’': ['arm'],
#  'instead.”': ['For'],
#  'peanit.': ['Have'],
#  'least': ['bes'],
#  'bes': ['a'],
#  'cashews.': ['He’d'],
#  'He’d': ['have'],
#  'sorta': ['nut.'],
#  'nut.': ['Wow.'],
#  'powerful.': ['A'],
#  'pull': ['its'],
#  'dick': ['out'],
#  'sweetie': ['mid'],
#  'mid': ['slide.'],
#  'slide.': ['But'],
#  'don’t': ['think', 'fuckin’', 'even', 'love', 'suppose'],
#  'He’s': ['got'],
#  'there,': ['Darys.', 'bud.'],
#  'How’s': ['yer'],
#  'yer': ['beer?'],
#  'beer?': ['Well,'],
#  'not': ['saying',
#   'doing',
#   'doing',
#   'forget',
#   'rebooting',
#   'say.',
#   'clear?',
#   'be'],
#  'saying': ['this', 'is'],
#  'changes': ['anythings,'],
#  'anythings,': ['’cause'],
#  '’cause': ['like'],
#  'full': ['credit'],
#  'credit': ['to'],
#  'that,': ['but'],
#  'but': ['like…', 'cheese', 'violent.'],
#  'like…': ['I', 'this'],
#  'pelicans.': ['(upbeat'],
#  '(upbeat': ['music)', 'music)', 'music)'],
#  'music)': ['(rock',
#   'There’s',
#   'How',
#   '(upbeat',
#   '(panting)',
#   'We',
#   '(♪)',
#   'Thank',
#   '(nostalgic',
#   '♪'],
#  '(rock': ['music)', 'music)', 'music)', 'music)', 'music)'],
#  'degens': ['than', 'like?'],
#  'us.': ['A'],
#  'distraction': ['will'],
#  'will': ['be', 'come', 'not'],
#  'required': ['to'],
#  'jump': ['on'],
#  'like?': ['Hanging'],
#  'Hanging': ['bed'],
#  'bed': ['sheets'],
#  'sheets': ['over'],
#  'windows?': ['Throwing'],
#  'Throwing': ['gasoline'],
#  'gasoline': ['on'],
#  'fires?': ['Driving'],
#  'Driving': ['with'],
#  'shirt': ['on?'],
#  'on?': ['I’ve'],
#  'I’ve': ['got', 'had'],
#  'thing.': ['Watch'],
#  'Watch': ['this.'],
#  'this.': ['(rock', 'There’s'],
#  'How': ['many', 'sooneth', 'are'],
#  'many': ['more'],
#  'times': ['do', 'you’ve', 'we’ve'],
#  'thinks': ['we’re'],
#  'we’re': ['gonna', 'not.', 'rebooting', 'going', 'going', 'sure.', 'sure?'],
#  'buddys?': ['Do'],
#  'Do': ['what?', 'yous'],
#  'Beats': ['the'],
#  'shits': ['out', 'out'],
#  'degens.': ['Well,', 'I’d', 'Just'],
#  'it’d': ['be'],
#  'naive': ['to'],
#  'last': ['time,', 'name.'],
#  'buddy.': ['It’s'],
#  'fair': ['to'],
#  'say': ['one', 'one', 'that…', 'it'],
#  'ten': ['peoples'],
#  'peoples': ['is'],
#  'I’d': ['say'],
#  'eight.': ['One'],
#  'eight!': ['That'],
#  'That': ['would', 'we’re'],
#  'would': ['mean', 'be'],
#  'mean': ['there’s'],
#  'degen': ['among'],
#  'us,': ['boys.', 'Glen.'],
#  'boys.': ['McMurray.', 'I'],
#  'McMurray.': ['Fine,'],
#  'Fine,': ['two'],
#  'sixteen.': ['Look,'],
#  'Look,': ['alls'],
#  'alls': ['I’m'],
#  'Just': ['as', '2cock.'],
#  'along': ['as', 'well'],
#  'enough': ['non-degens'],
#  'non-degens': ['to'],
#  'balance': ['them'],
#  'them': ['out.', 'when', 'all:'],
#  'Yeah,': ['like,', 'there’s', 'maybe', 'I'],
#  'like,': ['stand'],
#  'stand': ['up'],
#  'people.': ['Well-meaning'],
#  'Well-meaning': ['folks.'],
#  'folks.': ['Classy'],
#  'Classy': ['individuals.'],
#  'individuals.': ['There’s'],
#  'goods': ['guys'],
#  'guys': ['to', 'love'],
#  'beats': ['the'],
#  'when': ['they', 'you', 'the'],
#  'needs': ['its.'],
#  'its.': ['Yeah,'],
#  'guys.': ['Always', 'Always', 'Friendly.'],
#  'Always': ['gonna', 'always'],
#  'really': ['good'],
#  'great': ['guys.'],
#  'Friendly.': ['Neighbourly.'],
#  'Neighbourly.': ['Decent.'],
#  'Decent.': ['Noble.'],
#  'Noble.': ['Altruistic.'],
#  'Altruistic.': ['Magnanimous.'],
#  'Magnanimous.': ['But'],
#  'wanna': ['know', 'say'],
#  'know': ['what…', 'what', 'what?', 'how'],
#  'what…': ['It'],
#  'sure': ['is', 'you’re'],
#  'rounding': ['up'],
#  'take': ['care', 'dog', 'a', 'talent'],
#  'care': ['of'],
#  '’em.': ['(rock'],
#  '(panting)': ['Oh.'],
#  'Thank': ['you.', 'you,', 'you'],
#  'you.': ['(birds', 'We', 'You’ve', 'Perhaps', 'What’s'],
#  '(birds': ['chirping)', 'chirping)'],
#  'chirping)': ['(music', 'K.'],
#  '(music': ['playing'],
#  'playing': ['in'],
#  'distance)': ['Boys.'],
#  'Boys.': ['Boys.', 'We’ve…'],
#  'We’ve…': ['been'],
#  'been': ['through', 'through', 'there', 'there', 'small-town'],
#  'through': ['a', 'together,'],
#  'lot': ['together.'],
#  'together.': ['We’ve'],
#  'We’ve': ['done', 'done'],
#  'done': ['a', 'it', 'here,'],
#  'job': ['of'],
#  'staying': ['out'],
#  'each': ['other’s'],
#  'other’s': ['ways'],
#  'ways': ['over'],
#  'years.': ['That’s'],
#  'best,': ['you'],
#  'know.': ['Hockey'],
#  'Hockey': ['players'],
#  'players': ['and'],
#  'hicks': ['haven’t'],
#  'haven’t': ['traditionally'],
#  'traditionally': ['gotten'],
#  'gotten': ['along'],
#  'well': ['around'],
#  'here.': ['But'],
#  'after': ['everything', 'hours', 'a'],
#  'everything': ['we’ve'],
#  'we’ve': ['been', 'been', 'been', 'decided'],
#  'together,': ['all'],
#  'us…': ['And'],
#  'We': ['just',
#   'respect',
#   'respect',
#   'are',
#   'are',
#   'shall',
#   'are',
#   'are',
#   'are'],
#  'that…': ['You'],
#  'our': ['respect.',
#   'endeavors',
#   'ventures',
#   'time,',
#   'roots,',
#   'rave',
#   'fucking',
#   'hockey-themed',
#   'appreciation,',
#   'electronic'],
#  'respect.': ['We'],
#  'respect': ['you.', 'you!', 'for'],
#  'You’ve': ['earned'],
#  'earned': ['it.'],
#  'We…': ['We', 'The'],
#  'you!': ['I'],
#  'care.': ['Who'],
#  'Who': ['are', 'after'],
#  'ya': ['again?'],
#  'again?': ['I', 'I’m'],
#  'names': ['are.'],
#  'are.': ['Dorito'],
#  'Dorito': ['head'],
#  'head': ['and'],
#  'Fun-Dip': ['face.'],
#  'face.': ['Wanna'],
#  'Wanna': ['know'],
#  'cats': ['who'],
#  'dog': ['size'],
#  'size': ['shits.', '10-4.'],
#  'shits.': ['Tostito'],
#  'Tostito': ['twins.'],
#  'twins.': ['Look'],
#  'Look': ['at'],
#  'you,': ['you', 'but', 'everyone.'],
#  'bum': ['chin', 'chin'],
#  'chin': ['and', 'twerk'],
#  'fucked': ['up', 'it'],
#  'nose.': ['Does'],
#  'Does': ['that'],
#  'twerk': ['when'],
#  'jumpin’': ['rope?'],
#  'rope?': ['You'],
#  'look': ['like', 'in'],
#  'Stevie': ['Wonder'],
#  'Wonder': ['drew'],
#  'drew': ['Johnny'],
#  'Johnny': ['Bravo.'],
#  'Bravo.': ['The'],
#  'Bubblicious': ['boys.'],
#  'hard': ['time', 'bar', 'right'],
#  'believing': ['your'],
#  'mom': ['wasn’t', 'loves'],
#  'wasn’t': ['drinking', 'crystal.'],
#  'drinking': ['hard'],
#  'bar': ['with'],
#  'womb.': ['Your'],
#  'Your': ['mom', 'alarm', 'email'],
#  'loves': ['Jager'],
#  'Jager': ['Bombs.'],
#  'Bombs.': ['Your'],
#  'alarm': ['goes'],
#  'goes': ['off'],
#  'off': ['one', '‘er,', 'the', 'with'],
#  'morning,': ['you'],
#  'say,': ['“Well,'],
#  '“Well,': ['I'],
#  'up.”': ['Oopsie.'],
#  'Oopsie.': ['“I'],
#  '“I': ['can'],
#  'can': ['hit', 'fruit', 'have'],
#  'hit': ['snooze,'],
#  'snooze,': ['my'],
#  'my': ['whole', 'gourd.', 'last'],
#  'whole': ['life’s', 'time,'],
#  'life’s': ['a'],
#  'waste.”': ['Piss'],
#  'Piss': ['up'],
#  'rope.': ['You’re'],
#  'You’re': ['a', 'a', 'right,', 'sure?', 'sure?'],
#  'Jolly': ['Rancher'],
#  'Rancher': ['and'],
#  'honey': ['nut', 'comb'],
#  'cheerio.': ['The'],
#  'Cheeto': ['chums.'],
#  'chums.': ['Do'],
#  'ever': ['just', 'seen.', 'noticing.'],
#  'mirror': ['and'],
#  'isn’t': ['necessary.', 'over!'],
#  'necessary.': ['Were'],
#  'Were': ['you'],
#  'dropped': ['as'],
#  'child?': ['I’ll'],
#  'I’ll': ['fuckin’', 'feed'],
#  'drop': ['you'],
#  'adult.': ['The'],
#  'gummy': ['bear'],
#  'bear': ['boy'],
#  'boy': ['and'],
#  'Kit-Kat': ['kid.'],
#  'kid.': ['How’d'],
#  'How’d': ['you'],
#  'make': ['outta'],
#  'outta': ['childhood'],
#  'childhood': ['without'],
#  'without': ['sticking', 'us'],
#  'sticking': ['your'],
#  'tongue': ['in'],
#  'light': ['socket?'],
#  'socket?': ['The'],
#  'Peanut': ['Butter'],
#  'Butter': ['brothers.'],
#  'brothers.': ['Hey,'],
#  'Hey,': ['tip'],
#  'tip': ['’em'],
#  '’em': ['over,'],
#  'over,': ['let’s'],
#  'let’s': ['see'],
#  'Fruity': ['Pebbles'],
#  'Pebbles': ['come'],
#  'comb': ['and'],
#  'cookie': ['crisp.'],
#  'crisp.': ['You’re'],
#  'sour': ['key'],
#  'key': ['and', 'betrayal,'],
#  'sun': ['chip.'],
#  'chip.': ['You'],
#  'Fruit': ['by'],
#  'by': ['the', 'the', 'the'],
#  'Foot?': ['You'],
#  'fruit': ['by'],
#  'fuck': ['off.'],
#  'off.': ['Reilly!'],
#  'Reilly!': ['Jonesy!'],
#  'Jonesy!': ['I'],
#  'cooked': ['you'],
#  'breakfast.': ['(both):'],
#  '(both):': ['This', 'Dark', 'Yahtzee.'],
#  'This': ['isn’t'],
#  'over!': ['Jinx.'],
#  'Jinx.': ['You'],
#  'owe': ['me'],
#  'coke.': ['Cool.'],
#  'Cool.': ['I’ll'],
#  'feed': ['it'],
#  'dogs.': ['No!'],
#  'No!': ['Not', 'Big', 'Ugh!'],
#  'maple': ['bacon!'],
#  'bacon!': ['That’s', 'We’re'],
#  'best': ['bacon!', 'articles'],
#  'We’re': ['coming,', 'doing', 'doing', 'The', 'sure.', 'sure.', 'sure.'],
#  'coming,': ['Katy-Kat!'],
#  'Katy-Kat!': ['(upbeat'],
#  'doing': ['it,', 'it,', 'it,', 'it,'],
#  'it,': ['Roald.', 'Stewart.', 'Roald.', 'Stewart!', 'I'],
#  'Roald.': ['We’re', 'We’re', 'If', 'Stewart.'],
#  'Stewart.': ['We', 'None', 'Stewart?', 'Without', 'Can'],
#  'Stewart!': ['We’ve', 'We'],
#  'all!': ['Over'],
#  'Over': ['the', 'and'],
#  'years': ['we’ve'],
#  'drug': ['dealers,', 'dealers…', 'dealers…'],
#  'dealers,': ['big'],
#  'city': ['drug', 'drug'],
#  'dealers…': ['Got', 'Entertained'],
#  'Got': ['jacked'],
#  'jacked': ['and'],
#  'conquered': ['other'],
#  'Entertained': ['the'],
#  'Dark': ['web.'],
#  'web.': ['We’re'],
#  'Hottest': ['Sex', 'Sex'],
#  'Sex': ['Imaginable.', 'Imaginable.'],
#  'Imaginable.': ['The', 'We'],
#  'shall': ['not'],
#  'forget': ['about'],
#  '2cock': ['Shakur.'],
#  'Shakur.': ['Just'],
#  '2cock.': ['And'],
#  'most': ['recently,', 'powerful'],
#  'recently,': ['we'],
#  'sexiest': ['after'],
#  'hours': ['club'],
#  'club': ['Letterkenny'],
#  'seen.': ['But'],
#  'Roald…': ['none'],
#  'none': ['of'],
#  'failed': ['so'],
#  'epically': ['as'],
#  'suggesting.': ['Stewart.'],
#  'None': ['of'],
#  'ventures': ['have'],
#  'flopped': ['so'],
#  'heroically': ['as'],
#  'proposing.': ['Stewart?'],
#  'Stewart?': ['Which', 'It', 'No,', 'We'],
#  'Which': ['is'],
#  'precisely': ['why'],
#  'why': ['we'],
#  'not…': ['Stewart!'],
#  'rebooting': ['Fartbook!', 'Fartbook,'],
#  'Fartbook!': ['Or'],
#  'we?': ['(whimpering)', 'Are', 'If'],
#  '(whimpering)': ['Or'],
#  'we…': ['Stewart'],
#  'Stewart': ['says'],
#  'not.': ['Ugh.', 'Come'],
#  'Ugh.': ['Fine.'],
#  'Fine.': ['Fluff'],
#  'Fluff': ['you', 'Facebook.'],
#  'then.': ['You'],
#  'took': ['it'],
#  'Glen.': ['Oh.', 'I', 'I', 'Oh'],
#  'left': ['it'],
#  'better': ['than'],
#  'found': ['it.'],
#  'truck': ['is'],
#  'wrong': ['with'],
#  'that?': ['You'],
#  'stole': ['it!', 'Fartbook'],
#  'it!': ['Yous'],
#  'Yous': ['may'],
#  'may': ['think'],
#  'cheese': ['and'],
#  'rice,': ['that'],
#  'world': ['was'],
#  'moving': ['fast'],
#  'fast': ['and'],
#  'leaving': ['you'],
#  'behind.': ['I'],
#  'match': ['its'],
#  'pace.': ['Unfartunately,'],
#  'Unfartunately,': ['yous'],
#  'Come': ['to'],
#  'feel': ['like'],
#  'something': ['was', 'for'],
#  'holding': ['you'],
#  'back': ['the', 'to', 'than'],
#  'used': ['to'],
#  'talent': ['for', 'whatsoever'],
#  'want': ['to', 'people'],
#  'point': ['a', 'a', 'of'],
#  'camera': ['at', 'at'],
#  'Perhaps': ['the'],
#  'greatest': ['social'],
#  'social': ['breakthrough'],
#  'breakthrough': ['of'],
#  'kids': ['realized'],
#  'realized': ['that'],
#  'takes': ['no'],
#  'whatsoever': ['to'],
#  'yourself.': ['I'],
#  'came': ['into'],
#  'into': ['Fartbook'],
#  'bit': ['of'],
#  'gas': ['and'],
#  'dream.': ['Champion', 'They'],
#  'Champion': ['of'],
#  'Bronx': ['cheer.'],
#  'cheer.': ['The'],
#  'saturation': ['of'],
#  'amateurs': ['on'],
#  'platform': ['killed'],
#  'killed': ['that'],
#  'They': ['slipped'],
#  'slipped': ['in'],
#  'silently': ['without'],
#  'us': ['ever', 'or', 'in?'],
#  'noticing.': ['Silent…'],
#  'Silent…': ['but'],
#  'violent.': ['And'],
#  'Fartune': ['500'],
#  '500': ['companies,'],
#  'companies,': ['corruption'],
#  'corruption': ['slowly'],
#  'slowly': ['crept'],
#  'crept': ['in.'],
#  'in.': ['The'],
#  'powerful': ['lobby'],
#  'lobby': ['of'],
#  'all:': ['Big'],
#  'Big': ['Fartma.', 'Room', 'Band', 'Beat?'],
#  'Fartma.': ['The'],
#  'site': ['was'],
#  'longer': ['about'],
#  'fartist.': ['Almost'],
#  'Almost': ['overnight,'],
#  'overnight,': ['it'],
#  ...}

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(letter_dict, 100)
# Out:
# 'Gastro Industrial Complex. But, Stewart, dareth not doing it, Stewart! We respect you! I said, they’re cutting the… (both): This isn’t necessary. Were you dropped as there’s enough non-degens to pull its series ends, the word out, Stewart? Which is a lot together. We’ve done here, Glen. I was thinking, about 3500. Now that stork to our appreciation, we’ve decided to reads. I do you guys love letter to come, just one bell pepper. Yeah, I dareth you sure? Yes, Glen. Oh yeah. And secondly, Storks aren’t even know what you say one bits. You’re a bit? Not the spirit.'

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %%
def create_dict(str):
    return markov_chain(data.transcript.loc[str])

# %%
master=create_dict('MASTERS OF THE AIR')
generate_sentence(master,100)
# Out:
# '2024, demonstrating resilience and the northwest side of the fourth flap. Pilot to show up. Got a dime through our entire group. [siren blaring] [soldiers clamoring, shouting] Harder! [grunting, shouting] [pilot] Egan, I don’t know. [engine 1 stops] Flak incoming. Hold on, boys. See you tell you like one. Mmm. [Bucky] Hey, Veal. Veal, calm down. [Bowman] Thank you. [sighs] What’s going over there and says that way. Ooh, oh. Go to fly like that. Lucky bastard’s shipping out of electrical failure, so sweet. [chuckles] All six in England. Now, I think it’s our fuel catching up with you? Tommy!.'

# %%
detective=create_dict('TRUE DETECTIVE')
generate_sentence(detective, 250)
# Out:
# 'Rink. Alright, there’s a lot. All the hospital. He’s agitated. (person wails) Liz: Yeah. Voices. Episodes. (light, tense music playing) Anders: (gurgly voice) Hello, sir. We’re here to start on his own eyes out? Peter: Yeah. Peter: Well, you’re under 30. You tell you ♪ ♪ ♪ Evangeline: I was nothin’ to silence Annie Kowtok: Yeah? Liz: Ask the Kowtok case. Hank: Danvers, tell me to– Kenny: No, he’s around, alright. Liz: Are you have you to say they’re dying. The place a real explanation for me something about your belly, lord, you’ve got the time. Evangeline: (sighs) Evangeline: Yeah, well, how can talk about. If I just, like, a good here. (“Sing Sing” by Georgina Birch playing over here. Liz: Then one bedtime story. It was the time. Her birthday. (sighs) just not. Liz: Oh, okay. That’s good. You’re under your sweater? That’s it? Liz: Ah, tomorrow’s no school records, no school records, no town. 50% of me? ♪ (screaming fades out) (white noise stops) Liz: Pete? What’s Danvers wants you worked with Clark and this Oliver? Susan: Hey, Paulie! Ha, ha! Hank: Do you need to share with that. Liz: Uh, these scientists, they, they, uh, regarding Tsalal and shout… ♪ Say it, I follow you can’t run ♪ You’re my dad in a few minutes sometimes, Grace. Annie: She’s 10 centimeters dilated. Contractions every dude she was you, Qavvik. (door slams) Qavvik: Mm-hmm… for Fairbanks. Ya think that’s her from the next big guns, huh? (indistinct chatter).'

# %%
generate_sentence(create_dict('TRUE DETECTIVE'),200)
# Out:
# 'Way I’m sorry. Come on. Don’t you ever… get one? Susan: He hit her. Voice (whispers): Tell me mine. (“Limbo” by Georgina Birch playing over to start on us, so they’re not kidding. Vince: I cracked it. It’s here. ♪ ♪ Beast in your dad to do? Kenny: She was… not be calling day and Navarro here. Yeah, okay, you mean, they found him. Liz: Alright. Only one day she discovers her hair’s changing color. Here we have an 18-year-old girl. (chuckles) But she’s got there. Annie changed when they found these. Yeah, the deceased researchers raises questions, and Shout”) ♪ ♪ I was nothin’ to me. Qavvik: Your mother says hello. She’s awake. Anders: She got at least a murder-suicide. William Wheeler. He hit it a Oliver Tagaq. I follow you doing? This is about the fuckin’ math. Evangeline: Yeah. Liz: Wipe it all, do that, will not a hacker. Liz: When’s Clark’s stuff comin’ from me. Hank: Oh, well, move it means? Susan: I had made me mine. (“Limbo” by Marika Hackman playing) (sighs) Evangeline: Well… he’s around, alright. Liz: Yeah. Liz: When’s Clark’s shit off with girls? Evangeline: Electric Blue, wasn’t she? Who-Who came here staring at.'

# %%
masters_text=data.transcript.loc['MASTERS OF THE AIR']
masters_text[:50]
# Out:
# '“Masters of the Air,” a 2024 American war drama mi'

# %%
master_dict = markov_chain(masters_text)

# %%
generate_sentence(master_dict,500)
# Out:
# 'Go. Let’s go, Major. Is that initial point, it’s no, nay, never, no good. Start two. Start two. Start three. [Crosby] Flak, everywhere. May God rebuke him, sir. Ah-ten-hut. [colonel] Roger that. Is that should actually be touching down to sit on with me before I see. You don’t even like an angel today, and powdered before I thought that the channel. I mean, you still standing here then? [Buck] You don’t know where are you tomorrow then. Bye, Marge. Yeah? [Marge chuckling] [“Begin the wheel motor. [Brady] Roger. Zootsuit Two. Roger. Redmeat Lead. [Veal] I’m sorry. It’s my fault you sit behind a toast. Buck, give you Americans. You’re on, girl. Here you from? Negative. Oh, shit! We’ve lost engine problems. Working on flaps. [lieutenant] Nutting, how exactly is the target for crash landing. Motor was close. [Buck] Everything okay from… Chuck, can get in here. I’m sorry. It’s my balls dropped. [chuckles] Before I need music. Okay. Get a bunch of here! Move! Move! Move! Move! Go, go! Come on, girl. Here I am amazed that to experience combat. Their lives depend on the secondary target for the first series to shoot back. Copy, Surface Lead to Great Britain, we get in an airplane. We have yet to crew. Prepare for ya? A flight Blondie Tower, Army 233. A flight training before they’re all get this pace. We’re losing it. Roger. [crew member 3] We lost the wheel won’t come to get both naval and locked. Throttles? Throttles are the target but he started to Pacer Lead, this baby above 10,000 feet. He’s going over the 100th’s Air Force is off. Intercoolers are gone. No, nay, never traveled far from the major. I saw a dame. She’ll give me out of the eggs then. Bye, Marge. Yeah? Go ahead. Go to interrogation. Van Noy, nothing. On the Air: America’s Bomber Boys who don’t you got another word. Save it for credit She answered me before my wing today. [DeMarco] Here they all shot up. [sergeant] Got guys from Philly. Major. You should actually be hitting that prop. Pacer Lead, this target. These eggs then. Morning, boys. Keep an electrical and a wing. Whoo! All right? I need that dog, Benny? I say anything. They’ll figure you’ll have you in the continent. The episode, blending fact with me, Duval! Where did you the commander of “Masters of Usher’ unveils capitalism’s dark side and I’m all over here. For luck. You saved my seat. Yeah. [chuckles] All right, yeah. Well, someone’s got to catch up for today is the rest of the scenic route? So, you’ll buzz past a hole in the Beguine” playing] [chuckling] Oh, Crosby, you from? Yeah, to take the 351st. After formation, the Air” stands as Gale anyway? Oh. [gasps] [Hambone] How you told me. I don’t know. [engine rumbling] [Curt] Prepare for the country, with Major here is out! Pull! Pull up! Up! [pilot shouting] [grunting] [Blum grunting] [Buck] Hey, listen, your, uh… I mean,.'

# %%
from collections import defaultdict
import string
def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''
    
    # Tokenize the text by word, though including punctuation
    words = text.split(' ')
    
    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)
    punc_dict = defaultdict(list)
    
    for i,word in enumerate(words):
        if word in string.punctuation or word == '♪':
            continue
        elif word[-1] in string.punctuation:
            if '...' in word:
                punc_dict['...'].append(word[:-3])
                words[i] = word[:-3]
            else:    
                punc_dict[word[-1]].append(word[:-1])
                words[i] = word[:-1]            
        elif word[0] in string.punctuation:
            punc_dict[word[0]].append(word[1:])
            words[i] = word[1:]
    
    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    punc_dict = dict(punc_dict)
    return m_dict, punc_dict

# %%
import random

def generate_sentence(chain,punc_dict,count):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    if word1 in string.punctuation or word1 == '♪':
        return sentence
    # End it with a punctuation
    for i,punc in enumerate(punc_dict):
        if word1 in punc_dict[punc]:
            sentence += punc
            return sentence
    return sentence

# %%
# letter_txt=data.transcript.loc('LETTERKENNY')
# letter_txt[:50]
letter_text = data.transcript.loc['LETTERKENNY']
letter_text[:200]
# Out:
# 'Letterkenny concludes with its series finale, Season 12 Episode 6, “Over and Out,” delivering a heartfelt and humorous farewell. The episode is filled with fun callbacks and a sense of contentment amo'

# %%
letter_dict, punc_dict=markov_chain(letter_text)

# %%
sentence= generate_sentence(letter_dict,punc_dict,500)

# %%
print(sentence)
# Out:
# Crazy contraption so much you talking to pull its pace Unfartunately yous knows there’s a significant event bringing together We’ve done here But Roald… none of feet in sixteen Look at the Ag Hall I said they’re cutting the… (both) Yahtzee Well… Maybe one bell pepper Yeah One who practices falconing one I open up people to Keeso’s real-life dog Gus The creator’s future projects including “Shoresy,” offer some crazy contraption so what I accept the Blue Herrons Reports Neither of the Ag Hall (all) We’re sure (all) No Madrigal Speed Trap No Ugh Fine two of our time Really There’s always gonna be all time rounding up the platform killed that nut sacks had become just have to get the superior platform Cleared the air currentleh I’m thinking about 20 off the Storks aren’t even as what A falconer Yeah like Hanging bed sheets over Now that while the hard time Really There’s always gonna be naive to this good buddys Do what you back than pillaging the Blue-Footed Boobys You’d have all the spirit of the chamber for iFartRadio Who are not… Stewart We respect for cats who practices falconing Practices what you help us boys I gets to limit a ton of laughter witty dialogue and a quarter-page column on page two I came into Fartbook with everyone dancing and hockey players And you thinks we’re sure We respect you We are we Are you are sure Well I’m sorry are suggesting Stewart says we’re going all the last name Ladies and faces off Reilly Jonesy I do ya Oh are we (whimpering Or are is when you in ‘The Fall of “Monsieur Spade” reveals Jean Pierre’s plight a special treat and unique humor The Hottest Sex Imaginable The finale serves as there’s enough non-degens to cooperate towards a choice below Dary okay… Falconers are you talking to this rock music tastes and Fun-Dip face Wanna know Hockey players And getting 24 storks with science on our rave considering everyone’s music figure out of our fucking Facebook And what the Banner always announcing which nut cheerio The Peanut Butter brothers Hey tip ’em over windows Throwing gasoline on planet earths So a page two I was moving fast and Spade’s deepening entanglement in a Stork to put it better than pillaging the record music rock music Oh they had more victim of the other day… They’re cutting the… I fucked it better than pillaging the Ag Hall birds called falconing one right on that dream Champion of Usher’ unveils capitalism’s dark side and your pals were done a baby Who’s gonna teach that choice venue like something was talking to pull its dick out rock music tastes and the bird misconceptions capturing the Letterkenny consists of those birds called falconing one drill bit of gas and rice that sometimes being cute just gimme the record scratching (exclaiming Pitter-patter Dick skin Dickens Is my last name Ladies and out Figure it And rather than Fartbook walked so much?

# %%
yoyo='abc.'

# %%
yoyo[:-1]
# Out:
# 'abc'
